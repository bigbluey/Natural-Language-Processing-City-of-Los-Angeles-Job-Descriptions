# %% [markdown]
# # City of Los Angeles - Job Bulletins/Descriptions

# %% [markdown]
# ### Helping the City of Los Angeles to Structure and Analyze its Job Descriptions Using NLTK

# %% [markdown]
# The City of Los Angeles faces a big hiring challenge: 1/3 of its 50,000 workers are eligible to retire by July of 2020. The city has partnered with Kaggle to create a competition to improve the job bulletins that will fill all those open positions.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# The content, tone, and format of job bulletins can influence the quality of the applicant pool. Overly-specific job requirements may discourage diversity. The Los Angeles Mayor’s Office wants to reimagine the city’s job bulletins by using text analysis to identify needed improvements.
#
# The goal is to convert a folder full of plain-text job postings into a single structured CSV file and then to use this data to: (1) identify language that can negatively bias the pool of applicants; (2) improve the diversity and quality of the applicant pool; and/or (3) make it easier to determine which promotions are available to employees in each job class.

# %% [markdown]
# Unsupervised Machine Learning
# * Topic Modeling
#
# * https://www.geeksforgeeks.org/readability-index-pythonnlp/
#
# * https://medium.com/@FastCompany/analyzing-the-subtle-bias-in-tech-companies-recruiting-emails-b9b3123b2991
#
# * Word Cloud
# * Count average number of words

# %%
# Install spaCy Library for Advanced Natural Language Processing in Python
# !pip install spacy
# !python -m spacy download en
# Out:
# Collecting en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz (11.1MB)
#      |████████████████████████████████| 11.1MB 322kB/s eta 0:00:01
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Stored in directory: /private/var/folders/x9/t5n99fyj2slgyqv_xbkbjz6r0000gn/T/pip-ephem-wheel-cache-6tbqjmuz/wheels/39/ea/3b/507f7df78be8631a7a3d7090962194cf55bc1158572c0be77f
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.0.0
#     Uninstalling en-core-web-sm-2.0.0:
#       Successfully uninstalled en-core-web-sm-2.0.0
# Successfully installed en-core-web-sm-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /Users/josephyon/anaconda3/lib/python3.6/site-packages/en_core_web_sm -->
# /Users/josephyon/anaconda3/lib/python3.6/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# Dependencies & Setup
import os, glob, sys
import nltk
import nltk.corpus

import spacy
from spacy.matcher import PhraseMatcher
import random

# %%
# Open All Files in Directory
all_files = os.listdir("data/Job Bulletins")
all_contents = []

for files in all_files:
    if files.endswith(".txt"):
        f = open("data/Job Bulletins/" + str(files), "r")
        all_contents.append(f.read())

# %%
print(all_contents[56])
# Out:
# POLICE CAPTAIN
#
# Class Code:       2244
# Open Date:  08-17-18
#  (Exam Open to Current City Employees)
#
# ANNUAL SALARY
#
# $150,649 to $177,271, $159,042 to $187,147, and $167,916 to $197,587
#
# NOTES:
#
# 1. Annual salary is at the start of the pay range. The current salary range is subject to change. You may confirm the starting salary with the hiring department before accepting a job offer.
# 2. Candidates from the eligible list are normally appointed to vacancies in the lower pay grade positions.
#
# DUTIES
#
# A Police Captain plans, organizes, and directs the work of sworn and civilian employees engaged in the operation of a geographical division or area, or a specialized or support division; applies sound supervisory principles and techniques in building and maintaining an effective work force; and does related work.
#
# REQUIREMENTS/MINIMUM QUALIFICATIONS
#
# 1. Two years of full-time paid experience as a Police Lieutenant in the Los Angeles Police Department (LAPD) by
# March 15, 2019 and
# 2. Graduation from an accredited four-year college or university.
#
# Under the policy of rounding experience to the nearest full month, continuous service as a Police Lieutenant beginning on or before March 29, 2017, meets the two year experience requirement.
#
# PROCESS NOTES
#
# 1. Applicants must list the name and location of the school, degree earned, and completion date in the Education section of the City application.
# 2. Applicants who have not completed their degree, but who have completed at least 90 semester or 135 quarter units may file for this examination, however, they cannot be appointed until they have submitted proof of receiving their degree. Applicants must list the total number of units completed, name and location of the school, and the anticipated graduation date in the Education section of the City application.
# 3. Original/official transcripts or degrees must be submitted to LAPD Personnel Division's Position Control Section, 100 West First Street, Room 228, (213) 486-4690 for review prior to appointment to Police Captain. Please note that copies will not be accepted. Degrees and transcripts do not have to be submitted prior to the exam, but must be received upon completion of the requisite degree from an accredited four-year college or university. Do NOT submit transcripts and degrees to the Personnel Department.
# 4. Please note that the required education must be from a college or university accredited by a City of Los Angeles recognized agency. A list of approved accrediting agencies can be found at http://per.lacity.org/Accredited%20Institutions%2008-21-08.pdf.
#
# WHERE TO APPLY
#
# Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are available at https://www.governmentjobs.com/careers/lacity/promotionaljobs  for Promotional Examinations.
#
# Only police experience shall be shown in the employment history part of the application and shall include the date of original appointment as a Police Officer and the date of each promotion. For service since appointment as a Police Lieutenant, show the date of each transfer to another bureau or type of assignment that lasted three months or longer.
#
# NOTE:
#
# Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.
#
# APPLICATION DEADLINE
#
# Applications must be received by THURSDAY, AUGUST 30, 2018.
#
# Examination Weight:  Training and Experience Questionnaire/Interview  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%
#
# The examination will consist of a 30% weighted Training and Experience Questionnaire and a 70% weighted interview, which will be combined to provide a single score for this examination. Candidates must complete both portions of the examination. The Training and Experience Questionnaire will be administered on S	ATURDAY, SEPTEMBER 15, 2018 in Los Angeles. Candidates will be notified by email of the time and location of the written test. Candidates may anticipate that PCs (personal computers) will be available to type their responses to the Training and Experience Questionnaire.
#
# The Training and Experience Questionnaire may examine the following competencies: Stress Tolerance, Composure, Objectivity, Resolves Conflict, Leadership, Community Relations, and Credibility. Additional information can be obtained by going to http://per.lacity.org/index.cfm?content=jobanalyses and clicking on Competencies under Police Captain.  The Training and Experience Questionnaire for all candidates will be submitted to an expert review panel for evaluation. The expert review panel will assign a numerical score to each candidate based on an assessment of each candidate's qualifications as described on the Training and Experience Questionnaire. Assessors for the Training and Experience Questionnaire will consist of members from LAPD.
#
# The interview will be based on the assessment of each candidate's background, experience, and quality of performance, particularly at a supervisory level, as they have prepared the candidate to perform the duties of a Police Captain. In the interview, candidates may be examined on the following competencies: Leadership, Composure, Stress Tolerance, Objectivity, Resolves Conflict, Community Relations, and Credibility. LAPD personnel folders will be used.  Assessors for the Interview may consist of members from LAPD, other law enforcement agencies, and the community.
#
# CERTIFICATION
#
# Candidates on the eligible list, which results from this examination and who become subject to a Board of Inquiry or disciplinary action during the life of this list may be withheld from certification or removed from the eligible list in accordance with Personnel Department Policy and/or bargaining agreement provisions.
#
# NOTES:
#
# 1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and, upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities. To request a disability accommodation, please complete the Disability Accommodation Form within 14 days of the submittal of the City application. The Disability Accommodation form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.
# 2. Applications are accepted subject to review to ensure that minimum qualifications are met. Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.
# 3. Candidates will accrue seniority credit at the rate of 0.10 of a point for each year of continuous service as a Police Lieutenant in the Los Angeles Police Department prior to January 1, 2019. A maximum of one point will be added to each candidate's score.
# 4. Unless otherwise stated, a minimum score of 65% in a weighted written test, including seniority credit, is necessary in order to be called for subsequent portions of the examination.
# 5. A final average score of 70% is required to be placed on the eligible list.
# 6. Appointment to this position is subject to a one-year probationary period as provided by Section 1011(a) of the Los Angeles City Charter.
#
#
# THIS EXAMINATION IS TO BE GIVEN
# ONLY ON A DEPARTMENTAL PROMOTIONAL BASIS
#
# The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.
# Class Code: 2244. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11-29-13
#
#
# AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER
#
# Class Code 2244 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .08-17-18

# %%
# # Codecs Open
# import codecs

# # Open All Files in Directory
# all_files = os.listdir("data/Job Bulletins")
# all_contents = []

# for files in all_files:
#     if files.endswith(".txt"):
#         f = codecs.open("data/Job Bulletins/" + str(files), "r", "utf-8")
#         all_contents.append(f.read())

# %%
# # Open All Files in Directory
# all_files = os.listdir("data/Job Bulletins")
# # print(all_files)

# for files in all_files:
#     if files.endswith(".txt"):
#         print(files)
#         f = open("data/Job Bulletins/" + str(files), "r")
#         contents = f.read()

# %% [markdown]
# ### Tokenization

# %% [markdown]
# * The process of breaking up strings into Tokens (small structures & units)
#     * Break complex sentence into words
#     * Understand the importance of each of the words with respect to the sentence
#     * Produce a structural description on an input sentence

# %%
# NLTK Downloader to Obtain the `punkt` Resource
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/josephyon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Convert List to String
all_contents_str = str(all_contents)
type(all_contents_str)
# Out:
# str

# %%
# Convert All Text to lower case to Remove Redundancies
all_contents_str = all_contents_str.lower()

# %%
# Tokenize Words in Job Bulletin Files

from nltk.tokenize import word_tokenize

contents_tokens = word_tokenize(all_contents_str)
contents_tokens
# Out:
# ['[',
#  "'senior",
#  'housing',
#  'inspector\\n\\nclass',
#  'code',
#  ':',
#  '4244\\nopen',
#  'date',
#  ':',
#  '04-27-18\\n',
#  '(',
#  'exam',
#  'open',
#  'to',
#  'current',
#  'city',
#  'employees',
#  ')',
#  '\\n\\nannual',
#  'salary',
#  '\\n\\n',
#  '$',
#  '90,410',
#  'to',
#  '$',
#  '109,306\\n\\nnote',
#  ':',
#  '\\n\\n1',
#  '.',
#  'annual',
#  'salary',
#  'is',
#  'at',
#  'the',
#  'start',
#  'of',
#  'the',
#  'pay',
#  'range',
#  '.',
#  'the',
#  'current',
#  'salary',
#  'range',
#  'is',
#  'subject',
#  'to',
#  'change',
#  '.',
#  'please',
#  'confirm',
#  'the',
#  'starting',
#  'salary',
#  'with',
#  'the',
#  'hiring',
#  'department',
#  'before',
#  'accepting',
#  'a',
#  'job',
#  'offer.\\n2',
#  '.',
#  'candidates',
#  'from',
#  'the',
#  'eligible',
#  'list',
#  'are',
#  'normally',
#  'appointed',
#  'to',
#  'vacancies',
#  'in',
#  'the',
#  'lower',
#  'pay',
#  'grade',
#  'positions.\\n\\nduties\\n\\na',
#  'senior',
#  'housing',
#  'inspector',
#  'supervises',
#  'employees',
#  'engaged',
#  'either',
#  'in',
#  'the',
#  'inspection',
#  'of',
#  'residential',
#  'rental',
#  'property',
#  'locations',
#  'for',
#  'conformance',
#  'to',
#  'housing',
#  'habitability',
#  ',',
#  'quality',
#  ',',
#  'and',
#  'property',
#  'maintenance',
#  'ordinances',
#  ';',
#  'or',
#  'in',
#  'the',
#  'investigation',
#  'of',
#  'code',
#  'violation',
#  'complaints',
#  'and',
#  'the',
#  'following',
#  'through',
#  'with',
#  'the',
#  'code',
#  'enforcement',
#  'process',
#  'by',
#  'way',
#  'of',
#  'litigation',
#  'or',
#  'administrative',
#  'abatement',
#  ';',
#  'and',
#  'personally',
#  'conducts',
#  'the',
#  'more',
#  'difficult',
#  'field',
#  'inspections.\\n\\nrequirement/minimum',
#  'qualification\\n\\ntwo',
#  'years',
#  'of',
#  'full-time',
#  'paid',
#  'experience',
#  'with',
#  'the',
#  'city',
#  'of',
#  'los',
#  'angeles',
#  'as',
#  'a',
#  'housing',
#  'inspector.\\n\\nthe',
#  'following',
#  'may',
#  'be',
#  'substituted',
#  'for',
#  'one',
#  'year',
#  'of',
#  'housing',
#  'inspector',
#  'experience',
#  ':',
#  '\\n\\n1',
#  '.',
#  'one',
#  'year',
#  'of',
#  'full-time',
#  'paid',
#  'experience',
#  'with',
#  'the',
#  'city',
#  'of',
#  'los',
#  'angeles',
#  'as',
#  'a',
#  'building',
#  'inspector',
#  ',',
#  'building',
#  'mechanical',
#  'inspector',
#  ',',
#  'plumbing',
#  'inspector',
#  ',',
#  'electrical',
#  'inspector',
#  ',',
#  'fire',
#  'sprinkler',
#  'inspector',
#  ',',
#  'or',
#  'heating',
#  'and',
#  'refrigeration',
#  'inspector',
#  ';',
#  'or\\n2',
#  '.',
#  'graduation',
#  'from',
#  'an',
#  'accredited',
#  'four-year',
#  'college',
#  'or',
#  'university',
#  'with',
#  'a',
#  'degree',
#  'in',
#  'industrial',
#  'technology',
#  ',',
#  'industrial',
#  'science',
#  ',',
#  'or',
#  'any',
#  'four-year',
#  'degree',
#  'from',
#  'an',
#  'accredited',
#  'college',
#  'or',
#  'university',
#  'with',
#  'at',
#  'least',
#  '18',
#  'semester',
#  'or',
#  '24',
#  'quarter',
#  'units',
#  'in',
#  'construction',
#  'management',
#  ',',
#  'construction',
#  'technology',
#  ',',
#  'engineering',
#  ',',
#  'fire',
#  'safety',
#  ',',
#  'or',
#  'inspection',
#  'technology.\\n\\nprocess',
#  'notes\\n\\n1',
#  '.',
#  'applicants',
#  'who',
#  'lack',
#  'six',
#  'months',
#  'or',
#  'less',
#  'of',
#  'the',
#  'required',
#  'experience',
#  'may',
#  'file',
#  'for',
#  'this',
#  'examination',
#  '.',
#  'however',
#  ',',
#  'they',
#  'can',
#  'not',
#  'be',
#  'appointed',
#  'until',
#  'the',
#  'full',
#  'experience',
#  'requirement',
#  'is',
#  'met',
#  '.',
#  '\\n2',
#  '.',
#  'a',
#  'valid',
#  'california',
#  'driver\\',
#  "'s",
#  'license',
#  'is',
#  'required',
#  'prior',
#  'to',
#  'appointment',
#  '.',
#  'applicants',
#  'will',
#  'be',
#  'disqualified',
#  'and',
#  'not',
#  'eligible',
#  'for',
#  'hire',
#  'if',
#  'their',
#  'record',
#  'within',
#  'the',
#  'last',
#  '36',
#  'months',
#  'reflects',
#  'three',
#  'or',
#  'more',
#  'moving',
#  'violations',
#  'and/or',
#  'at-fault',
#  'accidents',
#  ',',
#  'or',
#  'a',
#  'conviction',
#  'of',
#  'a',
#  'major',
#  'moving',
#  'violation',
#  '(',
#  'such',
#  'as',
#  'dui',
#  ')',
#  '.\\n3',
#  '.',
#  'please',
#  'note',
#  'that',
#  'qualifying',
#  'education',
#  'must',
#  'be',
#  'from',
#  'a',
#  'college',
#  'or',
#  'university',
#  'accredited',
#  'by',
#  'a',
#  'city',
#  'of',
#  'los',
#  'angeles',
#  'recognized',
#  'agency',
#  '.',
#  'a',
#  'list',
#  'of',
#  'approved',
#  'accrediting',
#  'agencies',
#  'can',
#  'be',
#  'found',
#  'at',
#  'http',
#  ':',
#  '//per.lacity.org/accredited',
#  '%',
#  '20institutions',
#  '%',
#  '2008-21-08.pdf.\\n4',
#  '.',
#  'candidates',
#  'completing',
#  'the',
#  'examination',
#  'process',
#  'will',
#  'be',
#  'contacted',
#  'by',
#  'the',
#  'personnel',
#  'department',
#  'to',
#  'provide',
#  'required',
#  'proof',
#  'of',
#  'qualifying',
#  'degree',
#  'and/or',
#  'coursework.\\n\\nwhere',
#  'to',
#  'apply\\n\\napplications',
#  'will',
#  'only',
#  'be',
#  'accepted',
#  'on-line',
#  '.',
#  'when',
#  'you',
#  'are',
#  'viewing',
#  'the',
#  'on-line',
#  'job',
#  'bulletin',
#  'of',
#  'your',
#  'choice',
#  ',',
#  'simply',
#  'scroll',
#  'to',
#  'the',
#  'top',
#  'of',
#  'the',
#  'page',
#  'and',
#  'select',
#  'the',
#  '``',
#  'apply',
#  "''",
#  'icon',
#  '.',
#  'on-line',
#  'job',
#  'bulletins',
#  'are',
#  'also',
#  'available',
#  'at',
#  'https',
#  ':',
#  '//www.governmentjobs.com/careers/lacity/promotionaljobs',
#  'for',
#  'promotional',
#  'examinations',
#  '.',
#  '\\n\\nnote',
#  ':',
#  '\\n\\napplicants',
#  'are',
#  'urged',
#  'to',
#  'apply',
#  'early',
#  'to',
#  'ensure',
#  'you',
#  'have',
#  'time',
#  'to',
#  'resolve',
#  'any',
#  'technical',
#  'issues',
#  'you',
#  'may',
#  'encounter.\\n\\n\\n\\napplication',
#  'deadline\\n\\napplications',
#  'must',
#  'be',
#  'received',
#  'by',
#  'thursday',
#  ',',
#  'may',
#  '10',
#  ',',
#  '2018.\\n\\nselection',
#  'process\\n\\nexamination',
#  'weight',
#  ':',
#  'essay',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.advisory\\n',
#  'interview',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '100',
#  '%',
#  '\\n\\nthe',
#  'examination',
#  'score',
#  'will',
#  'be',
#  'based',
#  'entirely',
#  'on',
#  'the',
#  'interview',
#  '.',
#  'in',
#  'the',
#  'interview',
#  ',',
#  'emphasis',
#  'may',
#  'be',
#  'placed',
#  'on',
#  'the',
#  'candidate\\',
#  "'s",
#  'experience',
#  ',',
#  'training',
#  'and',
#  'professional',
#  'development',
#  'as',
#  'they',
#  'have',
#  'provided',
#  'knowledge',
#  'of',
#  ':',
#  'the',
#  'city',
#  'of',
#  'los',
#  'angeles',
#  'municipal',
#  'code',
#  ',',
#  'uniform',
#  'housing',
#  'code',
#  'and',
#  'the',
#  'electrical',
#  ',',
#  'plumbing',
#  ',',
#  'and',
#  'mechanical',
#  'codes',
#  'as',
#  'they',
#  'apply',
#  'to',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'fire',
#  'code',
#  'and',
#  'safety',
#  'practices',
#  'and',
#  'procedures',
#  'related',
#  'to',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'code',
#  'regulations',
#  'and',
#  'interpretations',
#  'relating',
#  'to',
#  'residential',
#  'rental',
#  'housing',
#  'inspection',
#  'activities',
#  'and',
#  'enforcement',
#  'procedures',
#  ',',
#  'and',
#  'abatement',
#  'of',
#  'substandard',
#  'buildings',
#  ';',
#  'safety',
#  'principles',
#  'and',
#  'practices',
#  'sufficient',
#  'to',
#  'conduct',
#  'inspections',
#  'and',
#  'explain',
#  'safe',
#  'practices',
#  'to',
#  'employees',
#  'and',
#  'the',
#  'public',
#  ';',
#  'pertinent',
#  'city',
#  'and',
#  'personnel',
#  'department',
#  'rules',
#  ',',
#  'policies',
#  'and',
#  'procedures',
#  'including',
#  'equal',
#  'employment',
#  'opportunity',
#  '(',
#  'eeo',
#  ')',
#  'responsibilities',
#  'and',
#  'memoranda',
#  'of',
#  'understanding',
#  '(',
#  'mous',
#  ')',
#  'provisions',
#  'as',
#  'they',
#  'relate',
#  'to',
#  'subordinate',
#  'personnel',
#  ';',
#  'principles',
#  'and',
#  'practices',
#  'of',
#  'supervision',
#  'including',
#  'directing',
#  ',',
#  'assigning',
#  ',',
#  'motivating',
#  ',',
#  'training',
#  ',',
#  'disciplining',
#  ',',
#  'counseling',
#  ',',
#  'commending',
#  'and',
#  'evaluating',
#  'employees',
#  ';',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'conduct',
#  'inspections',
#  'of',
#  'residential',
#  'housing',
#  'units',
#  ';',
#  'deal',
#  'tactfully',
#  'and',
#  'effectively',
#  'with',
#  'the',
#  'public',
#  ',',
#  'renters',
#  ',',
#  'property',
#  'owners',
#  ',',
#  'and',
#  'city',
#  'officials',
#  ';',
#  'prepare',
#  'written',
#  'reports',
#  'and',
#  'memoranda',
#  'sufficient',
#  'to',
#  'explain',
#  'information',
#  ',',
#  'report',
#  'findings',
#  'and',
#  'provide',
#  'recommendations',
#  'in',
#  'a',
#  'clear',
#  'and',
#  'concise',
#  'manner',
#  ';',
#  'and',
#  'other',
#  'necessary',
#  'knowledge',
#  ',',
#  'skills',
#  ',',
#  'and',
#  'abilities.\\n\\ncandidates',
#  'will',
#  'be',
#  'notified',
#  'later',
#  'by',
#  'e-mail',
#  'of',
#  'the',
#  'date',
#  ',',
#  'time',
#  ',',
#  'and',
#  'location',
#  'of',
#  'the',
#  'interview',
#  ',',
#  'which',
#  'will',
#  'be',
#  'held',
#  'in',
#  'los',
#  'angeles',
#  '.',
#  'it',
#  'is',
#  'anticipated',
#  'that',
#  'interviews',
#  'will',
#  'begin',
#  'during',
#  'the',
#  'period',
#  'of',
#  'july',
#  '9',
#  ',',
#  '2018',
#  'to',
#  'july',
#  '20',
#  ',',
#  '2018.\\n\\nprior',
#  'to',
#  'the',
#  'interview',
#  ',',
#  'applicants',
#  'will',
#  'be',
#  'required',
#  'to',
#  'prepare',
#  'some',
#  'written',
#  'material',
#  'related',
#  'to',
#  'the',
#  'duties',
#  'and',
#  'responsibilities',
#  'of',
#  'a',
#  'senior',
#  'housing',
#  'inspector',
#  '.',
#  'this',
#  'essay',
#  'material',
#  'will',
#  'not',
#  'be',
#  'separately',
#  'scored',
#  ',',
#  'but',
#  'will',
#  'be',
#  'presented',
#  'to',
#  'the',
#  'interview',
#  'board',
#  'for',
#  'discussion',
#  'with',
#  'the',
#  'candidate',
#  'and',
#  'for',
#  'consideration',
#  'in',
#  'the',
#  'overall',
#  'evaluation',
#  'of',
#  'the',
#  'candidate',
#  '.',
#  'please',
#  'note',
#  'that',
#  'applicants',
#  'must',
#  'complete',
#  'the',
#  'advisory',
#  'essay',
#  'and',
#  'meet',
#  'minimum',
#  'qualifications',
#  'as',
#  'stated',
#  'on',
#  'this',
#  'bulletin',
#  'in',
#  'order',
#  'to',
#  'be',
#  'considered',
#  'further',
#  'in',
#  'the',
#  'examination',
#  'process.\\n\\nthe',
#  'advisory',
#  'essay',
#  'will',
#  'be',
#  'administered',
#  ...]

# %%
len(contents_tokens)
# Out:
# 1187048

# %%
# Remove Stop Words
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))
contents_tokens_list1 = [ ]
for token in contents_tokens:
    if token not in stop:
        contents_tokens_list1.append(token)
contents_tokens_list1
# Out:
# ['[',
#  "'senior",
#  'housing',
#  'inspector\\n\\nclass',
#  'code',
#  ':',
#  '4244\\nopen',
#  'date',
#  ':',
#  '04-27-18\\n',
#  '(',
#  'exam',
#  'open',
#  'current',
#  'city',
#  'employees',
#  ')',
#  '\\n\\nannual',
#  'salary',
#  '\\n\\n',
#  '$',
#  '90,410',
#  '$',
#  '109,306\\n\\nnote',
#  ':',
#  '\\n\\n1',
#  '.',
#  'annual',
#  'salary',
#  'start',
#  'pay',
#  'range',
#  '.',
#  'current',
#  'salary',
#  'range',
#  'subject',
#  'change',
#  '.',
#  'please',
#  'confirm',
#  'starting',
#  'salary',
#  'hiring',
#  'department',
#  'accepting',
#  'job',
#  'offer.\\n2',
#  '.',
#  'candidates',
#  'eligible',
#  'list',
#  'normally',
#  'appointed',
#  'vacancies',
#  'lower',
#  'pay',
#  'grade',
#  'positions.\\n\\nduties\\n\\na',
#  'senior',
#  'housing',
#  'inspector',
#  'supervises',
#  'employees',
#  'engaged',
#  'either',
#  'inspection',
#  'residential',
#  'rental',
#  'property',
#  'locations',
#  'conformance',
#  'housing',
#  'habitability',
#  ',',
#  'quality',
#  ',',
#  'property',
#  'maintenance',
#  'ordinances',
#  ';',
#  'investigation',
#  'code',
#  'violation',
#  'complaints',
#  'following',
#  'code',
#  'enforcement',
#  'process',
#  'way',
#  'litigation',
#  'administrative',
#  'abatement',
#  ';',
#  'personally',
#  'conducts',
#  'difficult',
#  'field',
#  'inspections.\\n\\nrequirement/minimum',
#  'qualification\\n\\ntwo',
#  'years',
#  'full-time',
#  'paid',
#  'experience',
#  'city',
#  'los',
#  'angeles',
#  'housing',
#  'inspector.\\n\\nthe',
#  'following',
#  'may',
#  'substituted',
#  'one',
#  'year',
#  'housing',
#  'inspector',
#  'experience',
#  ':',
#  '\\n\\n1',
#  '.',
#  'one',
#  'year',
#  'full-time',
#  'paid',
#  'experience',
#  'city',
#  'los',
#  'angeles',
#  'building',
#  'inspector',
#  ',',
#  'building',
#  'mechanical',
#  'inspector',
#  ',',
#  'plumbing',
#  'inspector',
#  ',',
#  'electrical',
#  'inspector',
#  ',',
#  'fire',
#  'sprinkler',
#  'inspector',
#  ',',
#  'heating',
#  'refrigeration',
#  'inspector',
#  ';',
#  'or\\n2',
#  '.',
#  'graduation',
#  'accredited',
#  'four-year',
#  'college',
#  'university',
#  'degree',
#  'industrial',
#  'technology',
#  ',',
#  'industrial',
#  'science',
#  ',',
#  'four-year',
#  'degree',
#  'accredited',
#  'college',
#  'university',
#  'least',
#  '18',
#  'semester',
#  '24',
#  'quarter',
#  'units',
#  'construction',
#  'management',
#  ',',
#  'construction',
#  'technology',
#  ',',
#  'engineering',
#  ',',
#  'fire',
#  'safety',
#  ',',
#  'inspection',
#  'technology.\\n\\nprocess',
#  'notes\\n\\n1',
#  '.',
#  'applicants',
#  'lack',
#  'six',
#  'months',
#  'less',
#  'required',
#  'experience',
#  'may',
#  'file',
#  'examination',
#  '.',
#  'however',
#  ',',
#  'appointed',
#  'full',
#  'experience',
#  'requirement',
#  'met',
#  '.',
#  '\\n2',
#  '.',
#  'valid',
#  'california',
#  'driver\\',
#  "'s",
#  'license',
#  'required',
#  'prior',
#  'appointment',
#  '.',
#  'applicants',
#  'disqualified',
#  'eligible',
#  'hire',
#  'record',
#  'within',
#  'last',
#  '36',
#  'months',
#  'reflects',
#  'three',
#  'moving',
#  'violations',
#  'and/or',
#  'at-fault',
#  'accidents',
#  ',',
#  'conviction',
#  'major',
#  'moving',
#  'violation',
#  '(',
#  'dui',
#  ')',
#  '.\\n3',
#  '.',
#  'please',
#  'note',
#  'qualifying',
#  'education',
#  'must',
#  'college',
#  'university',
#  'accredited',
#  'city',
#  'los',
#  'angeles',
#  'recognized',
#  'agency',
#  '.',
#  'list',
#  'approved',
#  'accrediting',
#  'agencies',
#  'found',
#  'http',
#  ':',
#  '//per.lacity.org/accredited',
#  '%',
#  '20institutions',
#  '%',
#  '2008-21-08.pdf.\\n4',
#  '.',
#  'candidates',
#  'completing',
#  'examination',
#  'process',
#  'contacted',
#  'personnel',
#  'department',
#  'provide',
#  'required',
#  'proof',
#  'qualifying',
#  'degree',
#  'and/or',
#  'coursework.\\n\\nwhere',
#  'apply\\n\\napplications',
#  'accepted',
#  'on-line',
#  '.',
#  'viewing',
#  'on-line',
#  'job',
#  'bulletin',
#  'choice',
#  ',',
#  'simply',
#  'scroll',
#  'top',
#  'page',
#  'select',
#  '``',
#  'apply',
#  "''",
#  'icon',
#  '.',
#  'on-line',
#  'job',
#  'bulletins',
#  'also',
#  'available',
#  'https',
#  ':',
#  '//www.governmentjobs.com/careers/lacity/promotionaljobs',
#  'promotional',
#  'examinations',
#  '.',
#  '\\n\\nnote',
#  ':',
#  '\\n\\napplicants',
#  'urged',
#  'apply',
#  'early',
#  'ensure',
#  'time',
#  'resolve',
#  'technical',
#  'issues',
#  'may',
#  'encounter.\\n\\n\\n\\napplication',
#  'deadline\\n\\napplications',
#  'must',
#  'received',
#  'thursday',
#  ',',
#  'may',
#  '10',
#  ',',
#  '2018.\\n\\nselection',
#  'process\\n\\nexamination',
#  'weight',
#  ':',
#  'essay',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.advisory\\n',
#  'interview',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '100',
#  '%',
#  '\\n\\nthe',
#  'examination',
#  'score',
#  'based',
#  'entirely',
#  'interview',
#  '.',
#  'interview',
#  ',',
#  'emphasis',
#  'may',
#  'placed',
#  'candidate\\',
#  "'s",
#  'experience',
#  ',',
#  'training',
#  'professional',
#  'development',
#  'provided',
#  'knowledge',
#  ':',
#  'city',
#  'los',
#  'angeles',
#  'municipal',
#  'code',
#  ',',
#  'uniform',
#  'housing',
#  'code',
#  'electrical',
#  ',',
#  'plumbing',
#  ',',
#  'mechanical',
#  'codes',
#  'apply',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'fire',
#  'code',
#  'safety',
#  'practices',
#  'procedures',
#  'related',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'code',
#  'regulations',
#  'interpretations',
#  'relating',
#  'residential',
#  'rental',
#  'housing',
#  'inspection',
#  'activities',
#  'enforcement',
#  'procedures',
#  ',',
#  'abatement',
#  'substandard',
#  'buildings',
#  ';',
#  'safety',
#  'principles',
#  'practices',
#  'sufficient',
#  'conduct',
#  'inspections',
#  'explain',
#  'safe',
#  'practices',
#  'employees',
#  'public',
#  ';',
#  'pertinent',
#  'city',
#  'personnel',
#  'department',
#  'rules',
#  ',',
#  'policies',
#  'procedures',
#  'including',
#  'equal',
#  'employment',
#  'opportunity',
#  '(',
#  'eeo',
#  ')',
#  'responsibilities',
#  'memoranda',
#  'understanding',
#  '(',
#  'mous',
#  ')',
#  'provisions',
#  'relate',
#  'subordinate',
#  'personnel',
#  ';',
#  'principles',
#  'practices',
#  'supervision',
#  'including',
#  'directing',
#  ',',
#  'assigning',
#  ',',
#  'motivating',
#  ',',
#  'training',
#  ',',
#  'disciplining',
#  ',',
#  'counseling',
#  ',',
#  'commending',
#  'evaluating',
#  'employees',
#  ';',
#  'ability',
#  'conduct',
#  'inspections',
#  'residential',
#  'housing',
#  'units',
#  ';',
#  'deal',
#  'tactfully',
#  'effectively',
#  'public',
#  ',',
#  'renters',
#  ',',
#  'property',
#  'owners',
#  ',',
#  'city',
#  'officials',
#  ';',
#  'prepare',
#  'written',
#  'reports',
#  'memoranda',
#  'sufficient',
#  'explain',
#  'information',
#  ',',
#  'report',
#  'findings',
#  'provide',
#  'recommendations',
#  'clear',
#  'concise',
#  'manner',
#  ';',
#  'necessary',
#  'knowledge',
#  ',',
#  'skills',
#  ',',
#  'abilities.\\n\\ncandidates',
#  'notified',
#  'later',
#  'e-mail',
#  'date',
#  ',',
#  'time',
#  ',',
#  'location',
#  'interview',
#  ',',
#  'held',
#  'los',
#  'angeles',
#  '.',
#  'anticipated',
#  'interviews',
#  'begin',
#  'period',
#  'july',
#  '9',
#  ',',
#  '2018',
#  'july',
#  '20',
#  ',',
#  '2018.\\n\\nprior',
#  'interview',
#  ',',
#  'applicants',
#  'required',
#  'prepare',
#  'written',
#  'material',
#  'related',
#  'duties',
#  'responsibilities',
#  'senior',
#  'housing',
#  'inspector',
#  '.',
#  'essay',
#  'material',
#  'separately',
#  'scored',
#  ',',
#  'presented',
#  'interview',
#  'board',
#  'discussion',
#  'candidate',
#  'consideration',
#  'overall',
#  'evaluation',
#  'candidate',
#  '.',
#  'please',
#  'note',
#  'applicants',
#  'must',
#  'complete',
#  'advisory',
#  'essay',
#  'meet',
#  'minimum',
#  'qualifications',
#  'stated',
#  'bulletin',
#  'order',
#  'considered',
#  'examination',
#  'process.\\n\\nthe',
#  'advisory',
#  'essay',
#  'administered',
#  'online',
#  '.',
#  'applicants',
#  'invited',
#  'participate',
#  'examination',
#  'receive',
#  'e-mail',
#  'city',
#  'los',
#  'angeles',
#  'outlining',
#  'specific',
#  'steps',
#  'needed',
#  'complete',
#  'online',
#  'advisory',
#  'essay',
#  '.',
#  'applicants',
#  'required',
#  'complete',
#  'online',
#  'advisory',
#  'essay',
#  'may',
#  '26',
#  ',',
#  '2018.',
#  'additional',
#  'instructions',
#  'sent',
#  'via',
#  'e-mail',
#  '.',
#  'applicants',
#  'fail',
#  'complete',
#  'advisory',
#  'essay',
#  'instructed',
#  'may',
#  'disqualified.\\n\\nnotes',
#  ':',
#  '\\n\\n1',
#  '.',
#  'covered',
#  'entity',
#  'fair',
#  'employment',
#  'housing',
#  'act',
#  'title',
#  'ii',
#  'americans',
#  'disabilities',
#  'act',
#  ',',
#  'city',
#  'los',
#  'angeles',
#  'discriminate',
#  'basis',
#  'disability',
#  'upon',
#  'request',
#  ',',
#  'provide',
#  'reasonable',
#  'accommodations',
#  'ensure',
#  'equal',
#  'access',
#  'programs',
#  ',',
#  'services',
#  ',',
#  'activities',
#  '.',
#  'request',
#  'disability',
#  'accommodation',
#  ',',
#  'please',
#  'complete',
#  'disability',
#  'accommodation',
#  'form',
#  'within',
#  '14',
#  'calendar',
#  'days',
#  'submittal',
#  'city',
#  'application',
#  '.',
#  'disability',
#  'accommodation',
#  'form',
#  'obtained',
#  'http',
#  ':',
#  '//per.lacity.org/exams/verify_disability.pdf.\\n2',
#  '.',
#  'applications',
#  'accepted',
#  'subject',
#  'review',
#  'ensure',
#  'minimum',
#  'qualifications',
#  'met',
#  '.',
#  'candidates',
#  'may',
#  'disqualified',
#  'time',
#  'determined',
#  'possess',
#  'minimum',
#  'qualifications',
#  'stated',
#  'bulletin.\\n3',
#  '.',
#  'final',
#  'average',
#  'score',
#  '70',
#  '%',
#  'required',
#  'placed',
#  'eligible',
#  'list.\\n4',
#  '.',
#  'must',
#  'received',
#  'regular',
#  'appointment',
#  'city',
#  'position',
#  'reserve',
#  'list',
#  'file',
#  'promotional',
#  'basis.\\n5',
#  '.',
#  'seniority',
#  'credit',
#  'rate',
#  '0.25',
#  'point',
#  'year',
#  'continuous',
#  'service',
#  'added',
#  'weighted',
#  'test',
#  'score',
#  'candidate.\\n6',
#  '.',
#  'accordance',
#  'civil',
#  'service',
#  'rule',
#  ',',
#  'sec',
#  '.',
#  '4.24',
#  ',',
#  'review',
#  'periods',
#  'may',
#  'combined',
#  '.',
#  'candidates',
#  'examination',
#  'process',
#  'may',
#  'file',
#  'protests',
#  'provided',
#  'sec',
#  '.',
#  '4.20',
#  ',',
#  '4.22',
#  '4.23',
#  'applicable',
#  'within',
#  'required',
#  'time',
#  'frame',
#  ';',
#  'however',
#  ',',
#  'personnel',
#  'department',
#  'may',
#  'respond',
#  'resolve',
#  'protests',
#  'prior',
#  'establishment',
#  'eligible',
#  'list.\\n\\nthis',
#  'examination',
#  'given',
#  '\\non',
#  'interdepartmental',
#  'promotional',
#  'basis\\n\\nthe',
#  'city',
#  'los',
#  'angeles',
#  'discriminate',
#  'basis',
#  'race',
#  ',',
#  'religion',
#  ',',
#  'national',
#  'origin',
#  ',',
#  'sex',
#  ',',
#  'age',
#  ',',
#  'marital',
#  'status',
#  ',',
#  'sexual',
#  'orientation',
#  ',',
#  'gender',
#  'identity',
#  ',',
#  'gender',
#  'expression',
#  ',',
#  'disability',
#  ',',
#  'creed',
#  ',',
#  'color',
#  ',',
#  'ancestry',
#  ',',
#  'medical',
#  'condition',
#  '(',
#  'cancer',
#  ')',
#  ',',
#  'acquired',
#  'immune',
#  'deficiency',
#  'syndrome.\\nclass',
#  'code',
#  '4244',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  ...]

# %%
len(contents_tokens_list1)
# Out:
# 848856

# %%
# Remove All Numbers and Punctuations Using Regular Expression
import re

punctuation = re.compile(r'[\\\\n\$-.?!,":;()|0-9]')
contents_tokens_list2 = [ ]
for token in contents_tokens_list1:
    word = punctuation.sub("", token)
    if len(word)>0:
        contents_tokens_list2.append(word)
contents_tokens_list2
# Out:
# ['[',
#  'seior',
#  'housig',
#  'ispectorclass',
#  'code',
#  'ope',
#  'date',
#  'exam',
#  'ope',
#  'curret',
#  'city',
#  'employees',
#  'aual',
#  'salary',
#  'ote',
#  'aual',
#  'salary',
#  'start',
#  'pay',
#  'rage',
#  'curret',
#  'salary',
#  'rage',
#  'subject',
#  'chage',
#  'please',
#  'cofirm',
#  'startig',
#  'salary',
#  'hirig',
#  'departmet',
#  'acceptig',
#  'job',
#  'offer',
#  'cadidates',
#  'eligible',
#  'list',
#  'ormally',
#  'appoited',
#  'vacacies',
#  'lower',
#  'pay',
#  'grade',
#  'positiosdutiesa',
#  'seior',
#  'housig',
#  'ispector',
#  'supervises',
#  'employees',
#  'egaged',
#  'either',
#  'ispectio',
#  'residetial',
#  'retal',
#  'property',
#  'locatios',
#  'coformace',
#  'housig',
#  'habitability',
#  'quality',
#  'property',
#  'maiteace',
#  'ordiaces',
#  'ivestigatio',
#  'code',
#  'violatio',
#  'complaits',
#  'followig',
#  'code',
#  'eforcemet',
#  'process',
#  'way',
#  'litigatio',
#  'admiistrative',
#  'abatemet',
#  'persoally',
#  'coducts',
#  'difficult',
#  'field',
#  'ispectiosrequiremet/miimum',
#  'qualificatiotwo',
#  'years',
#  'fulltime',
#  'paid',
#  'experiece',
#  'city',
#  'los',
#  'ageles',
#  'housig',
#  'ispectorthe',
#  'followig',
#  'may',
#  'substituted',
#  'oe',
#  'year',
#  'housig',
#  'ispector',
#  'experiece',
#  'oe',
#  'year',
#  'fulltime',
#  'paid',
#  'experiece',
#  'city',
#  'los',
#  'ageles',
#  'buildig',
#  'ispector',
#  'buildig',
#  'mechaical',
#  'ispector',
#  'plumbig',
#  'ispector',
#  'electrical',
#  'ispector',
#  'fire',
#  'sprikler',
#  'ispector',
#  'heatig',
#  'refrigeratio',
#  'ispector',
#  'or',
#  'graduatio',
#  'accredited',
#  'fouryear',
#  'college',
#  'uiversity',
#  'degree',
#  'idustrial',
#  'techology',
#  'idustrial',
#  'sciece',
#  'fouryear',
#  'degree',
#  'accredited',
#  'college',
#  'uiversity',
#  'least',
#  'semester',
#  'quarter',
#  'uits',
#  'costructio',
#  'maagemet',
#  'costructio',
#  'techology',
#  'egieerig',
#  'fire',
#  'safety',
#  'ispectio',
#  'techologyprocess',
#  'otes',
#  'applicats',
#  'lack',
#  'six',
#  'moths',
#  'less',
#  'required',
#  'experiece',
#  'may',
#  'file',
#  'examiatio',
#  'however',
#  'appoited',
#  'full',
#  'experiece',
#  'requiremet',
#  'met',
#  'valid',
#  'califoria',
#  'driver',
#  's',
#  'licese',
#  'required',
#  'prior',
#  'appoitmet',
#  'applicats',
#  'disqualified',
#  'eligible',
#  'hire',
#  'record',
#  'withi',
#  'last',
#  'moths',
#  'reflects',
#  'three',
#  'movig',
#  'violatios',
#  'ad/or',
#  'atfault',
#  'accidets',
#  'covictio',
#  'major',
#  'movig',
#  'violatio',
#  'dui',
#  'please',
#  'ote',
#  'qualifyig',
#  'educatio',
#  'must',
#  'college',
#  'uiversity',
#  'accredited',
#  'city',
#  'los',
#  'ageles',
#  'recogized',
#  'agecy',
#  'list',
#  'approved',
#  'accreditig',
#  'agecies',
#  'foud',
#  'http',
#  '//perlacityorg/accredited',
#  'istitutios',
#  'pdf',
#  'cadidates',
#  'completig',
#  'examiatio',
#  'process',
#  'cotacted',
#  'persoel',
#  'departmet',
#  'provide',
#  'required',
#  'proof',
#  'qualifyig',
#  'degree',
#  'ad/or',
#  'courseworkwhere',
#  'applyapplicatios',
#  'accepted',
#  'olie',
#  'viewig',
#  'olie',
#  'job',
#  'bulleti',
#  'choice',
#  'simply',
#  'scroll',
#  'top',
#  'page',
#  'select',
#  '``',
#  'apply',
#  'ico',
#  'olie',
#  'job',
#  'bulletis',
#  'also',
#  'available',
#  'https',
#  '//wwwgovermetjobscom/careers/lacity/promotioaljobs',
#  'promotioal',
#  'examiatios',
#  'ote',
#  'applicats',
#  'urged',
#  'apply',
#  'early',
#  'esure',
#  'time',
#  'resolve',
#  'techical',
#  'issues',
#  'may',
#  'ecouterapplicatio',
#  'deadlieapplicatios',
#  'must',
#  'received',
#  'thursday',
#  'may',
#  'selectio',
#  'processexamiatio',
#  'weight',
#  'essay',
#  'advisory',
#  'iterview',
#  'the',
#  'examiatio',
#  'score',
#  'based',
#  'etirely',
#  'iterview',
#  'iterview',
#  'emphasis',
#  'may',
#  'placed',
#  'cadidate',
#  's',
#  'experiece',
#  'traiig',
#  'professioal',
#  'developmet',
#  'provided',
#  'kowledge',
#  'city',
#  'los',
#  'ageles',
#  'muicipal',
#  'code',
#  'uiform',
#  'housig',
#  'code',
#  'electrical',
#  'plumbig',
#  'mechaical',
#  'codes',
#  'apply',
#  'existig',
#  'residetial',
#  'occupacies',
#  'fire',
#  'code',
#  'safety',
#  'practices',
#  'procedures',
#  'related',
#  'existig',
#  'residetial',
#  'occupacies',
#  'code',
#  'regulatios',
#  'iterpretatios',
#  'relatig',
#  'residetial',
#  'retal',
#  'housig',
#  'ispectio',
#  'activities',
#  'eforcemet',
#  'procedures',
#  'abatemet',
#  'substadard',
#  'buildigs',
#  'safety',
#  'priciples',
#  'practices',
#  'sufficiet',
#  'coduct',
#  'ispectios',
#  'explai',
#  'safe',
#  'practices',
#  'employees',
#  'public',
#  'pertiet',
#  'city',
#  'persoel',
#  'departmet',
#  'rules',
#  'policies',
#  'procedures',
#  'icludig',
#  'equal',
#  'employmet',
#  'opportuity',
#  'eeo',
#  'resposibilities',
#  'memorada',
#  'uderstadig',
#  'mous',
#  'provisios',
#  'relate',
#  'subordiate',
#  'persoel',
#  'priciples',
#  'practices',
#  'supervisio',
#  'icludig',
#  'directig',
#  'assigig',
#  'motivatig',
#  'traiig',
#  'discipliig',
#  'couselig',
#  'commedig',
#  'evaluatig',
#  'employees',
#  'ability',
#  'coduct',
#  'ispectios',
#  'residetial',
#  'housig',
#  'uits',
#  'deal',
#  'tactfully',
#  'effectively',
#  'public',
#  'reters',
#  'property',
#  'owers',
#  'city',
#  'officials',
#  'prepare',
#  'writte',
#  'reports',
#  'memorada',
#  'sufficiet',
#  'explai',
#  'iformatio',
#  'report',
#  'fidigs',
#  'provide',
#  'recommedatios',
#  'clear',
#  'cocise',
#  'maer',
#  'ecessary',
#  'kowledge',
#  'skills',
#  'abilitiescadidates',
#  'otified',
#  'later',
#  'email',
#  'date',
#  'time',
#  'locatio',
#  'iterview',
#  'held',
#  'los',
#  'ageles',
#  'aticipated',
#  'iterviews',
#  'begi',
#  'period',
#  'july',
#  'july',
#  'prior',
#  'iterview',
#  'applicats',
#  'required',
#  'prepare',
#  'writte',
#  'material',
#  'related',
#  'duties',
#  'resposibilities',
#  'seior',
#  'housig',
#  'ispector',
#  'essay',
#  'material',
#  'separately',
#  'scored',
#  'preseted',
#  'iterview',
#  'board',
#  'discussio',
#  'cadidate',
#  'cosideratio',
#  'overall',
#  'evaluatio',
#  'cadidate',
#  'please',
#  'ote',
#  'applicats',
#  'must',
#  'complete',
#  'advisory',
#  'essay',
#  'meet',
#  'miimum',
#  'qualificatios',
#  'stated',
#  'bulleti',
#  'order',
#  'cosidered',
#  'examiatio',
#  'processthe',
#  'advisory',
#  'essay',
#  'admiistered',
#  'olie',
#  'applicats',
#  'ivited',
#  'participate',
#  'examiatio',
#  'receive',
#  'email',
#  'city',
#  'los',
#  'ageles',
#  'outliig',
#  'specific',
#  'steps',
#  'eeded',
#  'complete',
#  'olie',
#  'advisory',
#  'essay',
#  'applicats',
#  'required',
#  'complete',
#  'olie',
#  'advisory',
#  'essay',
#  'may',
#  'additioal',
#  'istructios',
#  'set',
#  'via',
#  'email',
#  'applicats',
#  'fail',
#  'complete',
#  'advisory',
#  'essay',
#  'istructed',
#  'may',
#  'disqualifiedotes',
#  'covered',
#  'etity',
#  'fair',
#  'employmet',
#  'housig',
#  'act',
#  'title',
#  'ii',
#  'americas',
#  'disabilities',
#  'act',
#  'city',
#  'los',
#  'ageles',
#  'discrimiate',
#  'basis',
#  'disability',
#  'upo',
#  'request',
#  'provide',
#  'reasoable',
#  'accommodatios',
#  'esure',
#  'equal',
#  'access',
#  'programs',
#  'services',
#  'activities',
#  'request',
#  'disability',
#  'accommodatio',
#  'please',
#  'complete',
#  'disability',
#  'accommodatio',
#  'form',
#  'withi',
#  'caledar',
#  'days',
#  'submittal',
#  'city',
#  'applicatio',
#  'disability',
#  'accommodatio',
#  'form',
#  'obtaied',
#  'http',
#  '//perlacityorg/exams/verify_disabilitypdf',
#  'applicatios',
#  'accepted',
#  'subject',
#  'review',
#  'esure',
#  'miimum',
#  'qualificatios',
#  'met',
#  'cadidates',
#  'may',
#  'disqualified',
#  'time',
#  'determied',
#  'possess',
#  'miimum',
#  'qualificatios',
#  'stated',
#  'bulleti',
#  'fial',
#  'average',
#  'score',
#  'required',
#  'placed',
#  'eligible',
#  'list',
#  'must',
#  'received',
#  'regular',
#  'appoitmet',
#  'city',
#  'positio',
#  'reserve',
#  'list',
#  'file',
#  'promotioal',
#  'basis',
#  'seiority',
#  'credit',
#  'rate',
#  'poit',
#  'year',
#  'cotiuous',
#  'service',
#  'added',
#  'weighted',
#  'test',
#  'score',
#  'cadidate',
#  'accordace',
#  'civil',
#  'service',
#  'rule',
#  'sec',
#  'review',
#  'periods',
#  'may',
#  'combied',
#  'cadidates',
#  'examiatio',
#  'process',
#  'may',
#  'file',
#  'protests',
#  'provided',
#  'sec',
#  'applicable',
#  'withi',
#  'required',
#  'time',
#  'frame',
#  'however',
#  'persoel',
#  'departmet',
#  'may',
#  'respod',
#  'resolve',
#  'protests',
#  'prior',
#  'establishmet',
#  'eligible',
#  'listthis',
#  'examiatio',
#  'give',
#  'o',
#  'iterdepartmetal',
#  'promotioal',
#  'basisthe',
#  'city',
#  'los',
#  'ageles',
#  'discrimiate',
#  'basis',
#  'race',
#  'religio',
#  'atioal',
#  'origi',
#  'sex',
#  'age',
#  'marital',
#  'status',
#  'sexual',
#  'orietatio',
#  'geder',
#  'idetity',
#  'geder',
#  'expressio',
#  'disability',
#  'creed',
#  'color',
#  'acestry',
#  'medical',
#  'coditio',
#  'cacer',
#  'acquired',
#  'immue',
#  'deficiecy',
#  'sydromeclass',
#  'code',
#  'a',
#  'equal',
#  'employmet',
#  'opportuity',
#  'employerfor',
#  'additioal',
#  'iformatio',
#  'faqs',
#  'regardig',
#  'city',
#  's',
#  'hirig',
#  'process',
#  'please',
#  'go',
#  'http',
#  '//perlacityorg/idexcfm',
#  'cotet=employmettestigprocess',
#  'legislative',
#  'assistatclass',
#  'code',
#  'ope',
#  'date',
#  'exam',
#  'ope',
#  'curret',
#  'city',
#  'employees',
#  'aual',
#  'salary',
#  'otes',
#  'cadidates',
#  'eligible',
#  'list',
#  'ormally',
#  'appoited',
#  'vacacies',
#  'lower',
#  'pay',
#  'grade',
#  'positios',
#  'curret',
#  'salary',
#  'rage',
#  'subject',
#  'chage',
#  'may',
#  'cofirm',
#  'startig',
#  'salary',
#  'hirig',
#  'departmet',
#  'acceptig',
#  'job',
#  'offerdutiesa',
#  'legislative',
#  'assistat',
#  'serves',
#  'oe',
#  'coucil',
#  'committees',
#  'may',
#  'act',
#  'city',
#  'clerk',
#  's',
#  'represetative',
#  'coucil',
#  'meetigs',
#  'preparig',
#  'checkig',
#  'agedas',
#  'reports',
#  'attedig',
#  'meetigs',
#  'maitaiig',
#  'records',
#  'providig',
#  'miutes',
#  'supplyig',
#  'iformatio',
#  'coucil',
#  'coucil',
#  'committee',
#  'activitiesrequiremetoe',
#  'year',
#  'fulltime',
#  'paid',
#  'experiece',
#  'class',
#  'level',
#  'maagemet',
#  'aalyst',
#  'performig',
#  'professioal',
#  'admiistrative',
#  'legislative',
#  'research',
#  'aalytical',
#  'dutiesotes',
#  'qualifyig',
#  'work',
#  'experiece',
#  'gaied',
#  'outside',
#  'city',
#  'los',
#  'ageles',
#  'term',
#  '``',
#  'professioal',
#  'experiece',
#  'applies',
#  'positios',
#  'require',
#  'possessio',
#  'degree',
#  'accredited',
#  'fouryear',
#  'college',
#  'uiversity',
#  'order',
#  'obtai',
#  'positio',
#  'therefore',
#  'cosidered',
#  '``',
#  'professioal',
#  'ocity',
#  'qualifyig',
#  'experiece',
#  'must',
#  'gaied',
#  'positios',
#  'obtaiig',
#  'fouryear',
#  'degree',
#  'applicats',
#  'lack',
#  'six',
#  'moths',
#  'less',
#  'experiece',
#  'may',
#  'file',
#  'examiatio',
#  'however',
#  'appoited',
#  'full',
#  'experiece',
#  'requiremet',
#  'met',
#  'valid',
#  'califoria',
#  'driver',
#  's',
#  'licese',
#  'may',
#  'required',
#  'cadidates',
#  'may',
#  'eligible',
#  'appoitmet',
#  'positios',
#  'record',
#  'withi',
#  'last',
#  'moths',
#  'reflects',
#  'three',
#  'movig',
#  'violatios',
#  'ad/or',
#  'atfault',
#  'accidets',
#  'covictio',
#  'major',
#  'movig',
#  'violatio',
#  'dui',
#  'where',
#  'applyapplicatios',
#  'accepted',
#  'olie',
#  'viewig',
#  'olie',
#  'job',
#  'bulleti',
#  'choice',
#  'simply',
#  'scroll',
#  'top',
#  'page',
#  'select',
#  '``',
#  'apply',
#  'ico',
#  'olie',
#  'job',
#  'bulletis',
#  'also',
#  'available',
#  'http',
#  '//agecygovermetjobscom/lacity/defaultcfm',
#  'promotioaljobs=for',
#  'promotioal',
#  'examiatios',
#  'applicatio',
#  'deadlieapplicatios',
#  'must',
#  'received',
#  'thursday',
#  'october',
#  'ote',
#  'applicats',
#  'urged',
#  'apply',
#  'early',
#  'esure',
#  'time',
#  'resolve',
#  'techical',
#  'issues',
#  'may',
#  'ecouterselectio',
#  'processexamiatio',
#  'weights',
#  'essay',
#  'advisorytttttttttttt',
#  'iterview',
#  'the',
#  'examiatio',
#  'cosist',
#  'iterview',
#  'emphasis',
#  'placed',
#  'evaluatio',
#  'adequacy',
#  'ature',
#  'cadidate',
#  's',
#  'experiece',
#  'traiig',
#  'persoal',
#  'qualificatios',
#  'icludig',
#  'kowledge',
#  'fuctios',
#  'coucil',
#  'committees',
#  'city',
#  'clerk',
#  's',
#  'office',
#  'orgaizatio',
#  'coucil',
#  'offices',
#  'city',
#  'departmets',
#  'staffs',
#  'parliametary',
#  'procedure',
#  'robert',
#  's',
#  'rules',
#  'order',
#  'coucil',
#  'rules',
#  'city',
#  'charter',
#  'admiistrative',
#  'code',
#  'muicipal',
#  'code',
#  'cao',
#  'rules',
#  'mayor',
#  's',
#  'executive',
#  'directives',
#  'ordiaces',
#  'related',
#  'fuctios',
#  'coucil',
#  'committees',
#  'iteral',
#  'operatios',
#  'city',
#  'clerk',
#  's',
#  'office',
#  'fuctios',
#  'city',
#  'departmets',
#  'related',
#  'activities',
#  'ability',
#  'orgaize',
#  'iformatio',
#  'materials',
#  'order',
#  'maitai',
#  'complete',
#  'records',
#  'develop',
#  'adhere',
#  'schedules',
#  'meet',
#  'appropriate',
#  'timetables',
#  'use',
#  'idepedet',
#  'judgmet',
#  'sufficiet',
#  'sort',
#  'files',
#  'order',
#  'importace',
#  'summarize',
#  'critical',
#  'issues',
#  'write',
#  ...]

# %%
len(contents_tokens_list2)
# Out:
# 550779

# %%
# POS Tags to All Words and Convert Them to a Pandas DataFrame to Get the Count of all POS Tags

import pandas as pd
import numpy as np

tokens_pos_tag = nltk.pos_tag(contents_tokens_list2)
pos_df = pd.DataFrame(tokens_pos_tag, columns = ('word','POS'))
pos_sum = pos_df.groupby('POS', as_index=False).count()
pos_sum.sort_values(['word'], ascending=[False])
# Out:
#      POS    word
# 12    NN  208879
# 8     JJ  115381
# 15   NNS   78274
# 28   VBP   39126
# 26   VBD   23614
# 19    RB   17315
# 25    VB   16281
# 27   VBN   14980
# 11    MD   11931
# 29   VBZ    6417
# 7     IN    3996
# 3     CD    3214
# 13   NNP    2639
# 4     DT    2203
# 10   JJS    1217
# 20   RBR    1081
# 34    ``    1055
# 9    JJR     848
# 2     CC     552
# 6     FW     376
# 0      #     343
# 33   WRB     330
# 22    RP     308
# 21   RBS     143
# 16   PDT     125
# 17   PRP      68
# 18  PRP$      35
# 31    WP      12
# 32   WP$      11
# 14  NNPS       8
# 24    TO       5
# 30   WDT       5
# 5     EX       4
# 23   SYM       2
# 1     ''       1

# %%
# Filter the Nouns, Remove all Other POS Tags, such as Adjectives, Verbs, Adverbs etc.
filtered_pos = [ ]
for one in tokens_pos_tag:
    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS':
        filtered_pos.append(one)
len(filtered_pos)
# Out:
# 289800

# %%
# Use NLTK’s FreqDist() to get the Frequency Distribution of the Words, then Select the Top-100 Words
fdist_pos = nltk.FreqDist(filtered_pos)
top_100_words = fdist_pos.most_common(100)
print(top_100_words)
# Out:
# [(('city', 'NN'), 8818), (('cadidates', 'NNS'), 5539), (('applicats', 'NNS'), 4734), (('ageles', 'NNS'), 4181), (('los', 'NN'), 3910), (('time', 'NN'), 3695), (('qualificatios', 'NNS'), 3597), (('disability', 'NN'), 3401), (('test', 'NN'), 2931), (('list', 'NN'), 2885), (('job', 'NN'), 2505), (('service', 'NN'), 2489), (('experiece', 'NN'), 2307), (('esure', 'NN'), 2261), (('cadidate', 'NN'), 2255), (('basis', 'NN'), 2137), (('promotioal', 'NN'), 2071), (('work', 'NN'), 2070), (('score', 'NN'), 2029), (('iterview', 'NN'), 2010), (('positios', 'NNS'), 1896), (('withi', 'NN'), 1844), (('code', 'NN'), 1823), (('applicatio', 'NN'), 1788), (('form', 'NN'), 1774), (('ope', 'NN'), 1684), (('applicatios', 'NNS'), 1599), (('hirig', 'NN'), 1536), (('review', 'NN'), 1536), (('writte', 'NN'), 1507), (('positio', 'NN'), 1476), (('date', 'NN'), 1473), (('opportuity', 'NN'), 1472), (('rule', 'NN'), 1372), (('employees', 'NNS'), 1362), (('years', 'NNS'), 1358), (('accommodatio', 'NN'), 1353), (('geder', 'NN'), 1349), (('movig', 'NN'), 1226), (('requiremets', 'NNS'), 1216), (('employmet', 'NN'), 1207), (('s', 'NN'), 1199), (('process', 'NN'), 1197), (('priciples', 'NNS'), 1162), (('examiatio', 'NN'), 1161), (('activities', 'NNS'), 1160), (('order', 'NN'), 1149), (('qualifyig', 'NN'), 1124), (('services', 'NNS'), 1116), (('class', 'NN'), 1115), (('kowledge', 'NN'), 1106), (('programs', 'NNS'), 1089), (('skills', 'NNS'), 1071), (('coverage', 'NN'), 1063), (('rage', 'NN'), 1000), (('safety', 'NN'), 993), (('icludig', 'NN'), 991), (('iformatio', 'NN'), 989), (('procedures', 'NNS'), 967), (('water', 'NN'), 940), (('year', 'NN'), 934), (('practices', 'NNS'), 929), (('period', 'NN'), 915), (('employee', 'NN'), 909), (('departmet', 'NN'), 887), (('meet', 'NN'), 884), (('traiig', 'NN'), 877), (('systems', 'NNS'), 868), (('professioal', 'NN'), 856), (('please', 'NN'), 847), (('days', 'NNS'), 847), (('protests', 'NNS'), 845), (('moths', 'NNS'), 836), (('cosist', 'NN'), 828), (('provide', 'NN'), 820), (('title', 'NN'), 778), (('eeds', 'NNS'), 774), (('act', 'NN'), 772), (('ability', 'NN'), 761), (('additioal', 'NN'), 755), (('caledar', 'NN'), 751), (('pay', 'NN'), 744), (('otes', 'NNS'), 744), (('multiplechoice', 'NN'), 743), (('issues', 'NNS'), 742), (('maiteace', 'NN'), 737), (('beefit', 'NN'), 719), (('rules', 'NNS'), 718), (('atioal', 'NN'), 716), (('persoel', 'NN'), 713), (('access', 'NN'), 711), (('color', 'NN'), 709), (('techiques', 'NNS'), 708), (('status', 'NN'), 705), (('coditio', 'NN'), 705), (('choice', 'NN'), 701), (('age', 'NN'), 695), (('disabilities', 'NNS'), 694), (('etity', 'NN'), 690), (('violatios', 'NNS'), 686)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist_pos.plot(30,cumulative=False)
plt.show()

# %%
# Convert the List Into a DataFrame to Clean
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) 
top_words_df = top_words_df.drop('pos', 1)
top_words_df.head()
# Out:
#    count       Word
# 0   8818       city
# 1   5539  cadidates
# 2   4734  applicats
# 3   4181     ageles
# 4   3910        los

# %%
top_words_df
# Out:
#     count            Word
# 0    8818            city
# 1    5539       cadidates
# 2    4734       applicats
# 3    4181          ageles
# 4    3910             los
# 5    3695            time
# 6    3597   qualificatios
# 7    3401      disability
# 8    2931            test
# 9    2885            list
# 10   2505             job
# 11   2489         service
# 12   2307       experiece
# 13   2261           esure
# 14   2255        cadidate
# 15   2137           basis
# 16   2071      promotioal
# 17   2070            work
# 18   2029           score
# 19   2010        iterview
# 20   1896        positios
# 21   1844           withi
# 22   1823            code
# 23   1788      applicatio
# 24   1774            form
# 25   1684             ope
# 26   1599     applicatios
# 27   1536           hirig
# 28   1536          review
# 29   1507          writte
# ..    ...             ...
# 70    847            days
# 71    845        protests
# 72    836           moths
# 73    828          cosist
# 74    820         provide
# 75    778           title
# 76    774            eeds
# 77    772             act
# 78    761         ability
# 79    755       additioal
# 80    751         caledar
# 81    744             pay
# 82    744            otes
# 83    743  multiplechoice
# 84    742          issues
# 85    737        maiteace
# 86    719          beefit
# 87    718           rules
# 88    716          atioal
# 89    713         persoel
# 90    711          access
# 91    709           color
# 92    708       techiques
# 93    705          status
# 94    705         coditio
# 95    701          choice
# 96    695             age
# 97    694    disabilities
# 98    690           etity
# 99    686       violatios
#
# [100 rows x 2 columns]

# %%
# Use Wordcloud and Matplotlib Libraries to present In Form of a Wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

subset_pos = top_words_df[['Word', 'count']]
tuples_pos = [(x[0] + " ") * x[1] for x in subset_pos.values]
text = " ".join(tuples_pos)
wordcloud = WordCloud()
wordcloud.generate(text)

plt.figure(figsize=(20,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()

# %%
# Most Frequent Phrases - Most Frequent Bigrams (2 words) and Trigrams (3 words)
bgs = nltk.bigrams(contents_tokens)
fdist2 = nltk.FreqDist(bgs) # selecting bigrams from tokens
bgs_100 = fdist2.most_common(100) # top-100 bigrams
bgs_df = pd.DataFrame(bgs_100, columns = ('bigram','count'))
bgs_df.head()
# Out:
#        bigram   count
# 0      (., .)  150354
# 1   (of, the)    8791
# 2    (,, and)    7204
# 3  (will, be)    5961
# 4   (in, the)    5538

# %%
bgs_df['phrase'] = bgs_df['bigram'].apply(lambda x: x[0]+" "+ x[1]) # merging the tuple into a string
bgs_df['filter_bgs'] = bgs_df['phrase'].str.contains(punctuation) # finding strings with numbers and punctuation
bgs_df.head()
# Out:
#        bigram   count   phrase  filter_bgs
# 0      (., .)  150354      . .        True
# 1   (of, the)    8791   of the       False
# 2    (,, and)    7204    , and        True
# 3  (will, be)    5961  will be       False
# 4   (in, the)    5538   in the        True

# %%
bgs_df = bgs_df[bgs_df.filter_bgs == False] # removing strings with numbers and punctuation

bgs_df = bgs_df.drop('bigram', 1)
bgs_df = bgs_df.drop('filter_bgs', 1) # removing the excess columns

bgs_df.reset_index()
bgs_df.head(10) #Final bigrams
# Out:
#     count    phrase
# 1    8791    of the
# 3    5961   will be
# 6    3921  the city
# 7    3660    to the
# 9    3423    of los
# 10   3391   city of
# 11   3126    may be
# 14   2479      of a
# 21   2165     to be
# 23   2131  with the

# %%
# Remove Stop Words
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))
contents_tokens_list1 = [ ]
for token in contents_tokens:
    if token not in stop:
        contents_tokens_list1.append(token)
contents_tokens_list1
# Out:
# ['[',
#  "'senior",
#  'housing',
#  'inspector\\n\\nclass',
#  'code',
#  ':',
#  '4244\\nopen',
#  'date',
#  ':',
#  '04-27-18\\n',
#  '(',
#  'exam',
#  'open',
#  'current',
#  'city',
#  'employees',
#  ')',
#  '\\n\\nannual',
#  'salary',
#  '\\n\\n',
#  '$',
#  '90,410',
#  '$',
#  '109,306\\n\\nnote',
#  ':',
#  '\\n\\n1',
#  '.',
#  'annual',
#  'salary',
#  'start',
#  'pay',
#  'range',
#  '.',
#  'current',
#  'salary',
#  'range',
#  'subject',
#  'change',
#  '.',
#  'please',
#  'confirm',
#  'starting',
#  'salary',
#  'hiring',
#  'department',
#  'accepting',
#  'job',
#  'offer.\\n2',
#  '.',
#  'candidates',
#  'eligible',
#  'list',
#  'normally',
#  'appointed',
#  'vacancies',
#  'lower',
#  'pay',
#  'grade',
#  'positions.\\n\\nduties\\n\\na',
#  'senior',
#  'housing',
#  'inspector',
#  'supervises',
#  'employees',
#  'engaged',
#  'either',
#  'inspection',
#  'residential',
#  'rental',
#  'property',
#  'locations',
#  'conformance',
#  'housing',
#  'habitability',
#  ',',
#  'quality',
#  ',',
#  'property',
#  'maintenance',
#  'ordinances',
#  ';',
#  'investigation',
#  'code',
#  'violation',
#  'complaints',
#  'following',
#  'code',
#  'enforcement',
#  'process',
#  'way',
#  'litigation',
#  'administrative',
#  'abatement',
#  ';',
#  'personally',
#  'conducts',
#  'difficult',
#  'field',
#  'inspections.\\n\\nrequirement/minimum',
#  'qualification\\n\\ntwo',
#  'years',
#  'full-time',
#  'paid',
#  'experience',
#  'city',
#  'los',
#  'angeles',
#  'housing',
#  'inspector.\\n\\nthe',
#  'following',
#  'may',
#  'substituted',
#  'one',
#  'year',
#  'housing',
#  'inspector',
#  'experience',
#  ':',
#  '\\n\\n1',
#  '.',
#  'one',
#  'year',
#  'full-time',
#  'paid',
#  'experience',
#  'city',
#  'los',
#  'angeles',
#  'building',
#  'inspector',
#  ',',
#  'building',
#  'mechanical',
#  'inspector',
#  ',',
#  'plumbing',
#  'inspector',
#  ',',
#  'electrical',
#  'inspector',
#  ',',
#  'fire',
#  'sprinkler',
#  'inspector',
#  ',',
#  'heating',
#  'refrigeration',
#  'inspector',
#  ';',
#  'or\\n2',
#  '.',
#  'graduation',
#  'accredited',
#  'four-year',
#  'college',
#  'university',
#  'degree',
#  'industrial',
#  'technology',
#  ',',
#  'industrial',
#  'science',
#  ',',
#  'four-year',
#  'degree',
#  'accredited',
#  'college',
#  'university',
#  'least',
#  '18',
#  'semester',
#  '24',
#  'quarter',
#  'units',
#  'construction',
#  'management',
#  ',',
#  'construction',
#  'technology',
#  ',',
#  'engineering',
#  ',',
#  'fire',
#  'safety',
#  ',',
#  'inspection',
#  'technology.\\n\\nprocess',
#  'notes\\n\\n1',
#  '.',
#  'applicants',
#  'lack',
#  'six',
#  'months',
#  'less',
#  'required',
#  'experience',
#  'may',
#  'file',
#  'examination',
#  '.',
#  'however',
#  ',',
#  'appointed',
#  'full',
#  'experience',
#  'requirement',
#  'met',
#  '.',
#  '\\n2',
#  '.',
#  'valid',
#  'california',
#  'driver\\',
#  "'s",
#  'license',
#  'required',
#  'prior',
#  'appointment',
#  '.',
#  'applicants',
#  'disqualified',
#  'eligible',
#  'hire',
#  'record',
#  'within',
#  'last',
#  '36',
#  'months',
#  'reflects',
#  'three',
#  'moving',
#  'violations',
#  'and/or',
#  'at-fault',
#  'accidents',
#  ',',
#  'conviction',
#  'major',
#  'moving',
#  'violation',
#  '(',
#  'dui',
#  ')',
#  '.\\n3',
#  '.',
#  'please',
#  'note',
#  'qualifying',
#  'education',
#  'must',
#  'college',
#  'university',
#  'accredited',
#  'city',
#  'los',
#  'angeles',
#  'recognized',
#  'agency',
#  '.',
#  'list',
#  'approved',
#  'accrediting',
#  'agencies',
#  'found',
#  'http',
#  ':',
#  '//per.lacity.org/accredited',
#  '%',
#  '20institutions',
#  '%',
#  '2008-21-08.pdf.\\n4',
#  '.',
#  'candidates',
#  'completing',
#  'examination',
#  'process',
#  'contacted',
#  'personnel',
#  'department',
#  'provide',
#  'required',
#  'proof',
#  'qualifying',
#  'degree',
#  'and/or',
#  'coursework.\\n\\nwhere',
#  'apply\\n\\napplications',
#  'accepted',
#  'on-line',
#  '.',
#  'viewing',
#  'on-line',
#  'job',
#  'bulletin',
#  'choice',
#  ',',
#  'simply',
#  'scroll',
#  'top',
#  'page',
#  'select',
#  '``',
#  'apply',
#  "''",
#  'icon',
#  '.',
#  'on-line',
#  'job',
#  'bulletins',
#  'also',
#  'available',
#  'https',
#  ':',
#  '//www.governmentjobs.com/careers/lacity/promotionaljobs',
#  'promotional',
#  'examinations',
#  '.',
#  '\\n\\nnote',
#  ':',
#  '\\n\\napplicants',
#  'urged',
#  'apply',
#  'early',
#  'ensure',
#  'time',
#  'resolve',
#  'technical',
#  'issues',
#  'may',
#  'encounter.\\n\\n\\n\\napplication',
#  'deadline\\n\\napplications',
#  'must',
#  'received',
#  'thursday',
#  ',',
#  'may',
#  '10',
#  ',',
#  '2018.\\n\\nselection',
#  'process\\n\\nexamination',
#  'weight',
#  ':',
#  'essay',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.advisory\\n',
#  'interview',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '100',
#  '%',
#  '\\n\\nthe',
#  'examination',
#  'score',
#  'based',
#  'entirely',
#  'interview',
#  '.',
#  'interview',
#  ',',
#  'emphasis',
#  'may',
#  'placed',
#  'candidate\\',
#  "'s",
#  'experience',
#  ',',
#  'training',
#  'professional',
#  'development',
#  'provided',
#  'knowledge',
#  ':',
#  'city',
#  'los',
#  'angeles',
#  'municipal',
#  'code',
#  ',',
#  'uniform',
#  'housing',
#  'code',
#  'electrical',
#  ',',
#  'plumbing',
#  ',',
#  'mechanical',
#  'codes',
#  'apply',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'fire',
#  'code',
#  'safety',
#  'practices',
#  'procedures',
#  'related',
#  'existing',
#  'residential',
#  'occupancies',
#  ';',
#  'code',
#  'regulations',
#  'interpretations',
#  'relating',
#  'residential',
#  'rental',
#  'housing',
#  'inspection',
#  'activities',
#  'enforcement',
#  'procedures',
#  ',',
#  'abatement',
#  'substandard',
#  'buildings',
#  ';',
#  'safety',
#  'principles',
#  'practices',
#  'sufficient',
#  'conduct',
#  'inspections',
#  'explain',
#  'safe',
#  'practices',
#  'employees',
#  'public',
#  ';',
#  'pertinent',
#  'city',
#  'personnel',
#  'department',
#  'rules',
#  ',',
#  'policies',
#  'procedures',
#  'including',
#  'equal',
#  'employment',
#  'opportunity',
#  '(',
#  'eeo',
#  ')',
#  'responsibilities',
#  'memoranda',
#  'understanding',
#  '(',
#  'mous',
#  ')',
#  'provisions',
#  'relate',
#  'subordinate',
#  'personnel',
#  ';',
#  'principles',
#  'practices',
#  'supervision',
#  'including',
#  'directing',
#  ',',
#  'assigning',
#  ',',
#  'motivating',
#  ',',
#  'training',
#  ',',
#  'disciplining',
#  ',',
#  'counseling',
#  ',',
#  'commending',
#  'evaluating',
#  'employees',
#  ';',
#  'ability',
#  'conduct',
#  'inspections',
#  'residential',
#  'housing',
#  'units',
#  ';',
#  'deal',
#  'tactfully',
#  'effectively',
#  'public',
#  ',',
#  'renters',
#  ',',
#  'property',
#  'owners',
#  ',',
#  'city',
#  'officials',
#  ';',
#  'prepare',
#  'written',
#  'reports',
#  'memoranda',
#  'sufficient',
#  'explain',
#  'information',
#  ',',
#  'report',
#  'findings',
#  'provide',
#  'recommendations',
#  'clear',
#  'concise',
#  'manner',
#  ';',
#  'necessary',
#  'knowledge',
#  ',',
#  'skills',
#  ',',
#  'abilities.\\n\\ncandidates',
#  'notified',
#  'later',
#  'e-mail',
#  'date',
#  ',',
#  'time',
#  ',',
#  'location',
#  'interview',
#  ',',
#  'held',
#  'los',
#  'angeles',
#  '.',
#  'anticipated',
#  'interviews',
#  'begin',
#  'period',
#  'july',
#  '9',
#  ',',
#  '2018',
#  'july',
#  '20',
#  ',',
#  '2018.\\n\\nprior',
#  'interview',
#  ',',
#  'applicants',
#  'required',
#  'prepare',
#  'written',
#  'material',
#  'related',
#  'duties',
#  'responsibilities',
#  'senior',
#  'housing',
#  'inspector',
#  '.',
#  'essay',
#  'material',
#  'separately',
#  'scored',
#  ',',
#  'presented',
#  'interview',
#  'board',
#  'discussion',
#  'candidate',
#  'consideration',
#  'overall',
#  'evaluation',
#  'candidate',
#  '.',
#  'please',
#  'note',
#  'applicants',
#  'must',
#  'complete',
#  'advisory',
#  'essay',
#  'meet',
#  'minimum',
#  'qualifications',
#  'stated',
#  'bulletin',
#  'order',
#  'considered',
#  'examination',
#  'process.\\n\\nthe',
#  'advisory',
#  'essay',
#  'administered',
#  'online',
#  '.',
#  'applicants',
#  'invited',
#  'participate',
#  'examination',
#  'receive',
#  'e-mail',
#  'city',
#  'los',
#  'angeles',
#  'outlining',
#  'specific',
#  'steps',
#  'needed',
#  'complete',
#  'online',
#  'advisory',
#  'essay',
#  '.',
#  'applicants',
#  'required',
#  'complete',
#  'online',
#  'advisory',
#  'essay',
#  'may',
#  '26',
#  ',',
#  '2018.',
#  'additional',
#  'instructions',
#  'sent',
#  'via',
#  'e-mail',
#  '.',
#  'applicants',
#  'fail',
#  'complete',
#  'advisory',
#  'essay',
#  'instructed',
#  'may',
#  'disqualified.\\n\\nnotes',
#  ':',
#  '\\n\\n1',
#  '.',
#  'covered',
#  'entity',
#  'fair',
#  'employment',
#  'housing',
#  'act',
#  'title',
#  'ii',
#  'americans',
#  'disabilities',
#  'act',
#  ',',
#  'city',
#  'los',
#  'angeles',
#  'discriminate',
#  'basis',
#  'disability',
#  'upon',
#  'request',
#  ',',
#  'provide',
#  'reasonable',
#  'accommodations',
#  'ensure',
#  'equal',
#  'access',
#  'programs',
#  ',',
#  'services',
#  ',',
#  'activities',
#  '.',
#  'request',
#  'disability',
#  'accommodation',
#  ',',
#  'please',
#  'complete',
#  'disability',
#  'accommodation',
#  'form',
#  'within',
#  '14',
#  'calendar',
#  'days',
#  'submittal',
#  'city',
#  'application',
#  '.',
#  'disability',
#  'accommodation',
#  'form',
#  'obtained',
#  'http',
#  ':',
#  '//per.lacity.org/exams/verify_disability.pdf.\\n2',
#  '.',
#  'applications',
#  'accepted',
#  'subject',
#  'review',
#  'ensure',
#  'minimum',
#  'qualifications',
#  'met',
#  '.',
#  'candidates',
#  'may',
#  'disqualified',
#  'time',
#  'determined',
#  'possess',
#  'minimum',
#  'qualifications',
#  'stated',
#  'bulletin.\\n3',
#  '.',
#  'final',
#  'average',
#  'score',
#  '70',
#  '%',
#  'required',
#  'placed',
#  'eligible',
#  'list.\\n4',
#  '.',
#  'must',
#  'received',
#  'regular',
#  'appointment',
#  'city',
#  'position',
#  'reserve',
#  'list',
#  'file',
#  'promotional',
#  'basis.\\n5',
#  '.',
#  'seniority',
#  'credit',
#  'rate',
#  '0.25',
#  'point',
#  'year',
#  'continuous',
#  'service',
#  'added',
#  'weighted',
#  'test',
#  'score',
#  'candidate.\\n6',
#  '.',
#  'accordance',
#  'civil',
#  'service',
#  'rule',
#  ',',
#  'sec',
#  '.',
#  '4.24',
#  ',',
#  'review',
#  'periods',
#  'may',
#  'combined',
#  '.',
#  'candidates',
#  'examination',
#  'process',
#  'may',
#  'file',
#  'protests',
#  'provided',
#  'sec',
#  '.',
#  '4.20',
#  ',',
#  '4.22',
#  '4.23',
#  'applicable',
#  'within',
#  'required',
#  'time',
#  'frame',
#  ';',
#  'however',
#  ',',
#  'personnel',
#  'department',
#  'may',
#  'respond',
#  'resolve',
#  'protests',
#  'prior',
#  'establishment',
#  'eligible',
#  'list.\\n\\nthis',
#  'examination',
#  'given',
#  '\\non',
#  'interdepartmental',
#  'promotional',
#  'basis\\n\\nthe',
#  'city',
#  'los',
#  'angeles',
#  'discriminate',
#  'basis',
#  'race',
#  ',',
#  'religion',
#  ',',
#  'national',
#  'origin',
#  ',',
#  'sex',
#  ',',
#  'age',
#  ',',
#  'marital',
#  'status',
#  ',',
#  'sexual',
#  'orientation',
#  ',',
#  'gender',
#  'identity',
#  ',',
#  'gender',
#  'expression',
#  ',',
#  'disability',
#  ',',
#  'creed',
#  ',',
#  'color',
#  ',',
#  'ancestry',
#  ',',
#  'medical',
#  'condition',
#  '(',
#  'cancer',
#  ')',
#  ',',
#  'acquired',
#  'immune',
#  'deficiency',
#  'syndrome.\\nclass',
#  'code',
#  '4244',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  ...]

# %%
# Most Frequent Phrases - Most Frequent Bigrams (2 words) and Trigrams (3 words)
tgs = nltk.trigrams(contents_tokens)
fdist3 = nltk.FreqDist(tgs) # selecting trigrams from tokens
tgs_100 = fdist3.most_common(100) # top-100 trigrams
tgs_df = pd.DataFrame(tgs_100, columns = ('trigram','count'))
tgs_df.head()
# Out:
#               trigram   count
# 0           (., ., .)  148288
# 1     (city, of, los)    3390
# 2  (of, los, angeles)    3355
# 3     (the, city, of)    2374
# 4     (will, not, be)    1817

# %%
tgs_df = tgs_df[tgs_df.filter_tgs == False] # removing strings with numbers and punctuation

tgs_df = tgs_df.drop('trigram', 1)
tgs_df = tgs_df.drop('filter_tgs', 1) # removing the excess columns

tgs_df.reset_index()
tgs_df.head(20) #Final trigrams
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0588580856eb> in <module>
# ----> 1 tgs_df = tgs_df[tgs_df.filter_tgs == False] # removing strings with numbers and punctuation
#       2
#       3 tgs_df = tgs_df.drop('trigram', 1)
#       4 tgs_df = tgs_df.drop('filter_tgs', 1) # removing the excess columns
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'filter_tgs'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

subset_pos = tgs_df[['bigram', 'count']]
tuples_pos = [(x[0] + " ") * x[1] for x in subset_pos.values]
text = " ".join(tuples_pos)
wordcloud = WordCloud()
wordcloud.generate(text)

plt.figure(figsize=(20,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-ff05dfc3cf5f> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 subset_pos = tgs_df[['bigram', 'count']]
#       5 tuples_pos = [(x[0] + " ") * x[1] for x in subset_pos.values]
#       6 text = " ".join(tuples_pos)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['bigram'] not in index"

# %%
# Install Word Cloud
# !pip install wordcloud

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# https://www.datacamp.com/community/tutorials/wordcloud-python

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(all_contents)

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# nltk.download('stopwords')

# # https://towardsdatascience.com/gentle-start-to-natural-language-processing-using-python-6e46c07addf3

# from nltk.corpus import stopwords

# sr = stopwords.words('english')
# clean_tokens = contents_tokens[:]
# for token in contents_tokens:
#     if token in stopwords.words('english'):
        
#         clean_tokens.remove(token)
# freq = nltk.FreqDist(clean_tokens)
# for key,val in freq.items():
#     print(str(key) + ':' + str(val))
# freq.plot(20, cumulative=False)

# %%
# https://levelup.gitconnected.com/machine-learning-with-python-nlp-and-text-recognition-94444d55b0ef

# %%
# TF-IDF (term frequency-inverse document frequency)
# https://monkeylearn.com/blog/what-is-tf-idf/

# %%
# Distinct Word Frequency Function
from nltk.probability import FreqDist
fdist = FreqDist()

# %%
for word in contents_tokens:
    fdist[word.lower()]+=1
fdist

# %%
# 25 Highest Frequency Words
fdist_top25 = fdist.most_common(25)
fdist_top25

# %%
# NLTK Downloader to Obtain the `averaged_perceptron_tagger` Resource
nltk.download('averaged_perceptron_tagger')

# %%
# POS: Parts of Speech

# %%
nltk.pos_tag(contents_tokens)

# %%
# NLTK Downloader to Obtain the `maxent_ne_chunker` Resource
nltk.download('maxent_ne_chunker')

# %%
# NER: Named Entity Recognition
from nltk import ne_chunk

nltk.chunk.ne_chunk(top_words_df)

# %%
# NLTK Downloader to Obtain the `words` Resource
nltk.download('words')

# %%
# Display a Parse Tree

# %%
nltk.download('treebank')

# %%
# from nltk.corpus import treebank
# t = treebank.parsed_sents('wsj_0001.mrg')[0]
# t.draw()

# %%
# Syntax Tree

# %%
import spacy
from spacy_readability import Readability

nlp = spacy.load('en')
read = Readability(nlp)
nlp.add_pipe(read, last=True)
doc = nlp("ZOO CURATOR OF EDUCATION 4300 091418)
doc._.flesch_kincaid_grade_level
doc._.flesch_kincaid_reading_ease
doc._.dale_chall
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-1822be9ff877> in <module>
#       3
#       4 nlp = spacy.load('en')
# ----> 5 read = Readability(nlp)
#       6 nlp.add_pipe(read, last=True)
#       7 doc = nlp("I am some really difficult text to read because I use obnoxiously large words.")
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
import spacy
from spacy_readability import Readability

nlp = spacy.load('en')
read = Readability(nlp)
nlp.add_pipe(read, last = True)
doc = nlp(contents_tokens)
doc._.flesch_kincaid_grade_level
doc._.flesch_kincaid_reading_ease
doc._.dale_chall
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-5dacdc02d12e> in <module>
#       3
#       4 nlp = spacy.load('en')
# ----> 5 read = Readability(nlp)
#       6 nlp.add_pipe(read, last = True)
#       7 doc = nlp(contents_tokens)
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
import spacy
from spacy_readability import Readability

nlp = spacy.load('en')
read = Readability(nlp)
nlp.add_pipe(read, last=True)

doc = nlp(contents_tokens)

print(doc._.flesch_kincaid_grade_level)
print(doc._.flesch_kincaid_reading_ease)
print(doc._.dale_chall)
print(doc._.smog)
print(doc._.coleman_liau_index)
print(doc._.automated_readability_index)
print(doc._.forcast)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-6a0253493c0f> in <module>
#       3
#       4 nlp = spacy.load('en')
# ----> 5 read = Readability(nlp)
#       6 nlp.add_pipe(read, last=True)
#       7
#
# TypeError: __init__() takes 1 positional argument but 2 were given
