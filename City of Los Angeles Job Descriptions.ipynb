# %% [markdown]
# # City of Los Angeles - Job Bulletins/Descriptions
# - Helping the City of Los Angeles to Structure and Analyze its Job Descriptions Using NLTK.

# %%
# Libraries

# Install spaCy Library for Advanced Natural Language Processing in Python
# !pip install spacy
# !python -m spacy download en

# %% [markdown]
# The City of Los Angeles faces a big hiring challenge: 1/3 of its 50,000 workers are eligible to retire by July of 2020. The city has partnered with Kaggle to create a competition to improve the job bulletins that will fill all those open positions.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# The content, tone, and format of job bulletins can influence the quality of the applicant pool. Overly-specific job requirements may discourage diversity. The Los Angeles Mayor’s Office wants to reimagine the city’s job bulletins by using text analysis to identify needed improvements.
#
# The goal is to convert a folder full of plain-text job postings into a single structured CSV file and then to use this data to: (1) identify language that can negatively bias the pool of applicants; (2) improve the diversity and quality of the applicant pool; and/or (3) make it easier to determine which promotions are available to employees in each job class.

# %% [markdown]
# Unsupervised Machine Learning
# - Topic Modeling
#
# - https://www.geeksforgeeks.org/readability-index-pythonnlp/
#
# - https://medium.com/@FastCompany/analyzing-the-subtle-bias-in-tech-companies-recruiting-emails-b9b3123b2991
#
# - Word Cloud
# - Count average number of words

# %%
# Dependencies & Setup

import os, glob, sys
import spacy
from spacy.matcher import PhraseMatcher
import random

# %%
# Retrive Data

# Method 1
# Open All Files in Directory
all_files = os.listdir("data/Job Bulletins")
# print(all_files)

# Get all the files in the folder and read their data 
for files in all_files:
    if (files != '.ipynb_checkpoints'):
        try:
            f = open("data/Job Bulletins/" + files, "r")
            contents = f.read()
        except:
            break         
# print(contents)

# %%
# Method 2
for all_files in glob.glob('*.txt'):
    print(all_files)

# %%
# Method 3
# Create a files array to hold all of the file names in the folder
files = []
# Folder Path
folder_path = "data/Job Bulletins"
# Iterate through all of the files in the folder path
counter = 0
for filename in glob.glob(os.path.join(folder_path, '*.txt')):
    with open(filename, 'r') as f:
        # Throw exception for file names that are not usable
        try:
            files.append(filename)
            counter += 1
        except:
            files.append('None')
print(f'Successfully retrieved {counter} files from folder.')
# Out:
# Successfully retrieved 684 files from folder.

# %%
# Create NLP pipeline

# nlp = English()
nlp = spacy.load('en')

# Model and languague data load and check
if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe('ner')
    nlp.add_pipe('ner')
else:
    nlp.get_pipe('ner')

# %%
# Create known lables and their entities

label = 'TITLE'
matcher = PhraseMatcher(nlp.vocab)
for i in ["ENGINEER", "Engineer",]:
    matcher.add(label, None, nlp(i))

# label = 'COLDEG'
# matcher = PhraseMatcher(nlp.vocab)
# for i in ["bachelor's degree", "university", "four-year college"]:
#     matcher.add(label, None, nlp(i))

# %%
# Define the offest function to turn string indexes into item indexes 

def offsetter(lbl, doc, matchitem):
    o_one = len(str(doc[0:matchitem[1]]))
    subdoc = doc[matchitem[1]:matchitem[2]]
    o_two = o_one + len(str(subdoc))
    return (o_one, o_two, lbl)

# %%
# Warning ⚠️: Will take a while if used on every file, recommend 
# using test_files for testing.
# Create docs and entities to train the model with the labels created

test_files = files[:10]
test_file = os.path.join('data/Job Bulletins/SENIOR SAFETY ENGINEER ELEVATORS 4264  042718.txt')

res = []
to_train_ents = []

for file_name in test_files:
    if (file_name != 'None'):
        with open(f'{test_file}') as jb:
            line = True
            while line:
                line = jb.readline()
                mnlp_line = nlp(line)
                matches = matcher(mnlp_line)
                res = [offsetter(label, mnlp_line, x)
                      for x
                      in matches]
                to_train_ents.append((line, 
                                      dict(entities=res)))

# %%
for ent in to_train_ents:
    if (ent[1] != {'entities': []}):
        print(ent)
# Out:
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})
# ('SENIOR SAFETY ENGINEER ELEVATORS\n', {'entities': [(13, 21, 'TITLE')]})
# ('A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n', {'entities': [(15, 23, 'TITLE'), (84, 92, 'TITLE')]})
# ('Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n', {'entities': [(50, 58, 'TITLE')]})
# ('4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n', {'entities': [(36, 44, 'TITLE')]})
# ("Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n", {'entities': [(335, 343, 'TITLE')]})

# %%
# Clean Data

# Remove empty lines...
counter = 0
for line in to_train_ents:
    if ([line[0]] == ['']):
        counter += 1
        to_train_ents.remove(line)
print(counter)
# Out:
# 10

# %%
# Warning ⚠️: This will use a lot of computer resources to run and will take a while, recommend 
# running on 1 epoch for testing. Although have on 20 for complete model.
# Train the model

optimizer = nlp.begin_training()

other_pipes = [pipe
              for pipe
              in nlp.pipe_names
              if pipe != 'ner']

# Epoch setting
epoch = 1

with nlp.disable_pipes(*other_pipes): # Only train NER
    for itn in range(epoch):
        losses = {}
        random.shuffle(to_train_ents)
        for item in to_train_ents:
#             print([item[0]])
            nlp.update([item[0]],
                       [item[1]],
                       sgd=optimizer,
                       drop=0.35,
                       losses=losses)
print(losses) # Error bounds
# Out:
# {'ner': 280.19521112589337}

# %%
# Test label-matcher

one = nlp("In order to apply for this job you need at least one bachelor's degree or a four-year college.\
          and/or university. Engineer.")
matches = matcher(one)
[match for match in matches]
# Out:
# [(12876033169774478903, 26, 27)]

# %%
# Test built-in label and entity matcher

to_analyze = ("Hello, my name is Xavier, and tonight we're in San Jose.")
doc = nlp(to_analyze)
ents = [(x.text, x.label_)
       for x in doc.ents]
print(ents)
# Out:
# []

# %%
# Test docs

to_train_ents = to_train_ents[:-1]
for item in to_train_ents:
            print([item[0]])
# Out:
# ['\n']
# ['\n']
# ['\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['Class Code:       4264\n']
# ['\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['\n']
# ['\n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['\n']
# ['\n']
# ['Open Date:  04-27-18\n']
# ['\n']
# ['APPLICATION DEADLINE\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['APPLICATION DEADLINE\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['\n']
# ['$83,415 to $121,939\n']
# ['\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['Candidates will be notified by e-mail of the date, time, and place of the interviews, which will be held in Los Angeles.  It is anticipated that interviews will begin during the period of JULY 2, 2018 to JULY 13, 2018.\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['NOTES:\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['DUTIES\n']
# ['\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['DUTIES\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['1. Applicants who lack six months or less of the above experience may file for this examination.  However, they cannot be appointed until the full experience requirement is met.\n']
# ['DUTIES\n']
# ['\n']
# ['\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['\n']
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['Candidates will be notified by e-mail of the date, time, and place of the interviews, which will be held in Los Angeles.  It is anticipated that interviews will begin during the period of JULY 2, 2018 to JULY 13, 2018.\n']
# ['APPLICATION DEADLINE\n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['1. Applicants who lack six months or less of the above experience may file for this examination.  However, they cannot be appointed until the full experience requirement is met.\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['\n']
# ['\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['\n']
# ['$83,415 to $121,939\n']
# ['Open Date:  04-27-18\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['\n']
# ['\n']
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['1. Applicants who lack six months or less of the above experience may file for this examination.  However, they cannot be appointed until the full experience requirement is met.\n']
# ['$83,415 to $121,939\n']
# ['\n']
# ['\n']
# ['\n']
# ['NOTES:\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['\n']
# ['\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['SELECTION PROCESS\n']
# ['\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['\n']
# ['\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['\n']
# ['\n']
# ['1. Applicants who lack six months or less of the above experience may file for this examination.  However, they cannot be appointed until the full experience requirement is met.\n']
# ['NOTE:\n']
# ['(Exam Open to Current City Employees)\n']
# ['\n']
# ['SELECTION PROCESS\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['Candidates will be notified by e-mail of the date, time, and place of the interviews, which will be held in Los Angeles.  It is anticipated that interviews will begin during the period of JULY 2, 2018 to JULY 13, 2018.\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['Candidates will be notified by e-mail of the date, time, and place of the interviews, which will be held in Los Angeles.  It is anticipated that interviews will begin during the period of JULY 2, 2018 to JULY 13, 2018.\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['NOTE:\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['DUTIES\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['\n']
# ['SELECTION PROCESS\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['NOTE:\n']
# ['\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['\n']
# ['\n']
# ['\n']
# ['NOTE:\n']
# ['\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['\n']
# ['\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['DUTIES\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['Open Date:  04-27-18\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['(Exam Open to Current City Employees)\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['Open Date:  04-27-18\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['\n']
# ['PROCESS NOTES\n']
# ['\n']
# ['\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['\n']
# ['\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['\n']
# ['NOTE:\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['(Exam Open to Current City Employees)\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['\n']
# ['\n']
# ['Class Code:       4264\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['DUTIES\n']
# ['Open Date:  04-27-18\n']
# ['$83,415 to $121,939\n']
# ['\n']
# ['\n']
# ['DUTIES\n']
# ['\n']
# ['NOTE:\n']
# ['\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['\n']
# ['Class Code:       4264\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['NOTE:\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['\n']
# ['\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['NOTES:\n']
# ['SELECTION PROCESS\n']
# ['\n']
# ['\n']
# ['\n']
# ['$83,415 to $121,939\n']
# ['\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['\n']
# ['\n']
# ["6. If in accordance with the Rule of Three Whole Scores all applicants are eligible for appointment consideration, the examination will consist entirely of an evaluation of the candidates' City application by Personnel Department staff to ensure that the minimum qualifications have been met.\n"]
# ['ANNUAL SALARY\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['\n']
# ['\n']
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['SELECTION PROCESS\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['\n']
# ['NOTE:\n']
# ['Class Code:       4264\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['SELECTION PROCESS\n']
# ['\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['\n']
# ['\n']
# ['\n']
# ['Notice:  \n']
# ['\n']
# ['NOTE:\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['$83,415 to $121,939\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['PROCESS NOTES\n']
# ['\n']
# ['(Exam Open to Current City Employees)\n']
# ['\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['\n']
# ['Class Code:       4264\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['APPLICATION DEADLINE\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['PROCESS NOTES\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['Class Code:       4264\n']
# ['\n']
# ['PROCESS NOTES\n']
# ['DUTIES\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['PROCESS NOTES\n']
# ['WHERE TO APPLY\n']
# ['NOTE:\n']
# ['$83,415 to $121,939\n']
# ['\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['\n']
# ['\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['\n']
# ['\n']
# ['\n']
# ['$83,415 to $121,939\n']
# ['Open Date:  04-27-18\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['\n']
# ['APPLICATION DEADLINE\n']
# ['1. As a covered entity under the Fair Employment and Housing Act and Title II of the Americans with Disabilities Act, the City of Los Angeles does not discriminate on the basis of disability and upon request, will provide reasonable accommodations to ensure equal access to its programs, services, and activities.  To request a disability accommodation, please complete the Disability Accommodation Form within 14 calendar days of the submittal of the City application.  The Disability Accommodation Form can be obtained at http://per.lacity.org/exams/verify_disability.pdf.\n']
# ['\n']
# ['\n']
# ...
# ['DUTIES\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['\n']
# ['\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['\n']
# ['\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['\n']
# ['\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['(Exam Open to Current City Employees)\n']
# ['\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['Class Code:       4264\n']
# ['\n']
# ['\n']
# ['\n']
# ['Applications will only be accepted on-line. When you are viewing the on-line job bulletin of your choice, simply scroll to the top of the page and select the "Apply" icon. On-line job bulletins are also available at https://www.governmentjobs.com/careers/lacity/promotionaljobs for Promotional Examinations. \n']
# ['\n']
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['\n']
# ['\n']
# ['$83,415 to $121,939\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['NOTE:\n']
# ['Class Code 4264 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .04-27-18\n']
# ['SELECTION PROCESS\n']
# ['NOTE:\n']
# ['\n']
# ['\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ['NOTES:\n']
# ['AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['Candidates will be notified by e-mail of the date, time, and place of the interviews, which will be held in Los Angeles.  It is anticipated that interviews will begin during the period of JULY 2, 2018 to JULY 13, 2018.\n']
# ['\n']
# ['A Senior Safety Engineer Elevators assigns, reviews and evaluates the work of Safety Engineer Elevators engaged in the inspection of escalators, elevators, and similar devices for conformance to State laws and City ordinances regulating their design, installation and operation; applies sound supervisory principles and techniques in building and maintaining an effective work force; and fulfills equal employment opportunity responsibilities.\n']
# ['THIS EXAMINATION IS TO BE GIVEN ONLY\n']
# ['\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ['2. Applications are accepted subject to review to ensure that minimum qualifications are met.  Candidates may be disqualified at any time if it is determined that they do not possess the minimum qualifications stated on this bulletin.\n']
# ['\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['5. Seniority credit at the rate of 0.25 of a point for each year of continuous service will be added to the weighted test score of each candidate.\n']
# ['\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['NOTE:\n']
# ['\n']
# ['\n']
# ['PROCESS NOTES\n']
# ['\n']
# ['ANNUAL SALARY\n']
# ['\n']
# ['(Exam Open to Current City Employees)\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ['Applications must be received by THURSDAY, MAY 10, 2018.\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['APPLICATION DEADLINE\n']
# ['\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['1. Applicants who lack six months or less of the above experience may file for this examination.  However, they cannot be appointed until the full experience requirement is met.\n']
# ['Two years of full-time paid experience as a Safety Engineer Elevators with the City of Los Angeles.\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['\n']
# ['\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['\n']
# ['Notice:  \n']
# ['DUTIES\n']
# ['\n']
# ['WHERE TO APPLY\n']
# ['PROCESS NOTES\n']
# ['\n']
# ['\n']
# ['REQUIREMENT/MINIMUM QUALIFICATION\n']
# ['\n']
# ['Examination Weight:  Interview . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 100%\n']
# ['NOTES:\n']
# ['\n']
# ['\n']
# ['3. A final average score of 70% is required to be placed on the eligible list.\n']
# ['\n']
# ['\n']
# ["For additional information and FAQs regarding the City's hiring process, please go to: http://per.lacity.org/index.cfm?content=employmenttestingprocess\n"]
# ["Your examination score will be based entirely on an evaluation of your professional and personal qualifications. In the interview, emphasis may be placed on an adequacy of the candidate's experience, training, education and personal qualifications as they have provided the background necessary to perform the duties of a Senior Safety Engineer Elevators including the knowledge of: elevator and escalator installation, operation and maintenance; engineering principles and practices applicable to the design and installation of escalators, elevators and similar lifting devices; inspection and testing methods related to escalators, elevators and similar lifting devices; City of Los Angeles Elevator Code, California Elevator Safety Orders, City of Los Angeles Electrical Code and other codes applicable to the installation and operation of escalators, elevators, and similar lifting devices; functions and procedures of the Elevator Inspection Section in the Department of Building and Safety; applicable accident prevention and investigations principle and practices relevant to escalators, elevators, and similar lifting devices; safety principles and practices; fundamental principles and practices of supervision, including  planning, delegating, directing, assigning, motivating, training, counseling, disciplining and evaluating work performance; pertinent City and Personnel Department rules, policies, and procedures including, Equal Employment Opportunity (EEO); and the ability to interpret plans and specifications for the installation of escalators and lifting equipment; analyze difficult problems and adopt an effective course of action; apply the provisions of the various laws and codes applicable to the installation and operation of escalators, elevators, and similar lifting devices to specific installations; detect unsafe conditions and practices and make decisions conforming to legal requirements and recognized safety practices; establish and maintain a work environment to enhance both employee morale and productivity; deal tactfully and effectively with other employees, contractors and the public; communicate orally in a clear, concise and convincing manner; and other necessary skills, knowledge and abilities.\n"]
# ['\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['4. You must have received a regular appointment to a City position or be on a reserve list to file on a promotional basis.\n']
# ['Notice:  \n']
# ['Notice:  \n']
# ['\n']
# ['\n']
# ['\n']
# ['NOTES:\n']
# ['\n']
# ['\n']
# ['NOTE:\n']
# ['\n']
# ['Open Date:  04-27-18\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['SELECTION PROCESS\n']
# ['If you receive and accept an offer of employment to a regular position with the City of Los Angeles, your employee benefit coverage (including health and dental coverage as well as life insurance) will commence approximately six weeks after your original regular appointment. Not all positions in the City receive benefit coverage; you should inquire regarding the availability of employee benefits prior to accepting a position.\n']
# ['7. In accordance with Civil Service Rule, Sec. 4.24, review periods may be combined. Candidates in the examination process may file protests as provided in Sec. 4.20, 4.22 and 4.23 as applicable and within the required time frame; however, the Personnel Department may respond to and resolve protests prior to the establishment of the eligible list. \n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['\n']
# ['ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['SENIOR SAFETY ENGINEER ELEVATORS\n']
# ['Applicants are urged to apply early to ensure you have time to resolve any technical issues you may encounter.\n']
# ['Annual salary is at the start of the pay range. The current salary range is subject to change. Please confirm the starting salary with the hiring department before accepting a job offer.\n']
# ['\n']
# ['PROCESS NOTES\n']
# ['4. Upon appointment, a Senior Safety Engineer Elevators will be required to furnish an automobile, properly insured, for use in City service.  Mileage will be paid on the basis of established rates.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ["3. A valid California driver's license is required.  Applicants will be disqualified and not eligible for hire if their record within the last 36 months reflects three or more moving violations and/or at-fault accidents, or a conviction of a major moving violation (such as DUI).\n"]
# ['$83,415 to $121,939\n']
# ['\n']
# ['2. A valid Certificate of Competency to Inspect Elevators issued by the California Division of Industrial Safety is required prior to appointment.\n']
# ['\n']
# ['The City of Los Angeles does not discriminate on the basis of race, religion, national origin, sex, age, marital status, sexual orientation, gender identity, gender expression, disability, creed, color, ancestry, medical condition (cancer), or Acquired Immune Deficiency Syndrome.\n']
# ['\n']

# %%
# Test model

# from spacy import displacy
# for item in to_train_ents:
#     displacy.render(one, style='dep')

# %% [markdown]
# # TO-DO:
# - Data Examination:
#     - What biases (positive/negative) are we trying to find? **Important
#     - How will we optimize each doc? (i.e. Skills, Pay, etc.)
#     - Are there important entities we should establish? (i.e. college degree, certain responsibilites, etc.)
#     - What text analyis could make these docs better?
